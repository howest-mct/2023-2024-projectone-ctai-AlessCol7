# %%
import yaml
import os

with open('data.yaml', 'r') as file:
    data = yaml.safe_load(file)

print("Train path:", os.path.exists(data['train']))
print("Validation path:", os.path.exists(data['val']))
print("Test path:", os.path.exists(data['test']))

def count_images(directory):
    supported_formats = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.tif')
    return len([name for name in os.listdir(directory) if name.lower().endswith(supported_formats)])

print(f" The number of images in training set: {count_images(data['train'])}")
print(f" The number of images in validation set: {count_images(data['val'])}")
print(f" The number of images in test set: {count_images(data['test'])}")
# Out:
# Train path: True
# Validation path: True
# Test path: True
#  The number of images in training set: 2694
#  The number of images in validation set: 236
#  The number of images in test set: 113

# %%
from ultralytics import YOLO
from pathlib import Path

absolute_from_relative_path = Path('data.yaml').resolve()

model = YOLO('yolov8n.pt')  # Load a pretrained model (recommended for training)
results = model.train(data=absolute_from_relative_path, epochs=40, imgsz=480)
# Out:
# New https://pypi.org/project/ultralytics/8.2.31 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.227 🚀 Python-3.9.18 torch-1.13.1 CPU (Apple M1)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v5i.yolov8/data.yaml, epochs=40, patience=50, batch=16, imgsz=480, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# Overriding model.yaml nc=80 with nc=18
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    754822  ultralytics.nn.modules.head.Detect           [18, [64, 128, 256]]
# Fontconfig warning: ignoring UTF-8: not a valid region tag
# [W NNPACK.cpp:53] Could not initialize NNPACK! Reason: Unsupported hardware.
# Model summary: 225 layers, 3014358 parameters, 3014342 gradients
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v5i.yolov8/train/labels.cache... 2694 images, 0 backgrounds, 0 corrupt: 100%|██████████| 2694/2694 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 927, len(boxes) = 14556. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Scanning /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v5i.yolov8/valid/labels.cache... 236 images, 0 backgrounds, 0 corrupt: 100%|██████████| 236/236 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 82, len(boxes) = 1129. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000455, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 480 train, 480 val
# Using 0 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 40 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/40         0G      1.595      3.258      1.386         45        480: 100%|██████████| 169/169 [10:26<00:00,  3.70s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.73s/it]
#                    all        236       1129      0.259      0.454      0.273      0.163
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/40         0G      1.409      1.926      1.249         71        480: 100%|██████████| 169/169 [09:58<00:00,  3.54s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:22<00:00,  2.79s/it]
#                    all        236       1129      0.265      0.708      0.385      0.231
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/40         0G      1.376      1.677       1.23         46        480: 100%|██████████| 169/169 [09:35<00:00,  3.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.68s/it]
#                    all        236       1129      0.356      0.653      0.469      0.298
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/40         0G      1.344       1.53      1.217         59        480: 100%|██████████| 169/169 [09:43<00:00,  3.45s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.63s/it]
#                    all        236       1129      0.495      0.682      0.648      0.409
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/40         0G      1.324      1.374      1.205         91        480: 100%|██████████| 169/169 [09:30<00:00,  3.37s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.69s/it]
#                    all        236       1129      0.693      0.752      0.775      0.504
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/40         0G      1.302      1.236      1.191         48        480: 100%|██████████| 169/169 [09:48<00:00,  3.48s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:20<00:00,  2.62s/it]
#                    all        236       1129      0.807      0.813      0.814      0.515
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/40         0G      1.279       1.13      1.183         24        480: 100%|██████████| 169/169 [09:36<00:00,  3.41s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.63s/it]
#                    all        236       1129      0.885      0.794      0.871      0.565
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/40         0G      1.277      1.066      1.176         39        480: 100%|██████████| 169/169 [09:46<00:00,  3.47s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.68s/it]
#                    all        236       1129      0.868      0.824      0.882      0.579
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/40         0G      1.271      1.029      1.169         19        480: 100%|██████████| 169/169 [09:45<00:00,  3.47s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.70s/it]
#                    all        236       1129      0.883      0.818      0.889      0.583
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/40         0G      1.249     0.9855      1.157         43        480: 100%|██████████| 169/169 [10:03<00:00,  3.57s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:22<00:00,  2.76s/it]
#                    all        236       1129        0.9      0.847       0.89      0.587
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/40         0G      1.229     0.9571      1.144         76        480: 100%|██████████| 169/169 [09:56<00:00,  3.53s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:22<00:00,  2.75s/it]
#                    all        236       1129      0.885      0.878       0.91      0.579
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/40         0G      1.212     0.9319       1.14         60        480: 100%|██████████| 169/169 [10:09<00:00,  3.61s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:22<00:00,  2.83s/it]
#                    all        236       1129      0.909      0.861      0.904      0.598
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/40         0G      1.195     0.8964      1.136         28        480: 100%|██████████| 169/169 [09:55<00:00,  3.52s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.65s/it]
#                    all        236       1129       0.89      0.875      0.913      0.605
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/40         0G      1.194     0.8799      1.133         48        480: 100%|██████████| 169/169 [09:51<00:00,  3.50s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.66s/it]
#                    all        236       1129      0.913      0.864      0.906      0.602
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/40         0G      1.158     0.8412       1.12         59        480: 100%|██████████| 169/169 [09:50<00:00,  3.50s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:22<00:00,  2.80s/it]
#                    all        236       1129      0.905       0.87      0.918      0.615
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/40         0G      1.165     0.8361      1.121         79        480: 100%|██████████| 169/169 [09:48<00:00,  3.48s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:22<00:00,  2.76s/it]
#                    all        236       1129      0.909      0.883      0.915      0.618
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/40         0G       1.17     0.8208      1.124         72        480: 100%|██████████| 169/169 [09:32<00:00,  3.39s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.73s/it]
#                    all        236       1129       0.91      0.883      0.926      0.619
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/40         0G      1.146      0.795      1.107         66        480: 100%|██████████| 169/169 [09:38<00:00,  3.42s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:22<00:00,  2.80s/it]
#                    all        236       1129      0.921      0.879      0.933      0.631
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/40         0G      1.122     0.7777      1.099         66        480: 100%|██████████| 169/169 [09:38<00:00,  3.43s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.75s/it]
#                    all        236       1129      0.914      0.874      0.926      0.637
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/40         0G      1.134     0.7826      1.105         32        480: 100%|██████████| 169/169 [09:46<00:00,  3.47s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.64s/it]
#                    all        236       1129      0.929      0.874      0.926      0.635
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/40         0G      1.113     0.7609      1.094         69        480: 100%|██████████| 169/169 [09:42<00:00,  3.45s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.72s/it]
#                    all        236       1129      0.927      0.883      0.928      0.632
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/40         0G      1.105     0.7419       1.09         20        480: 100%|██████████| 169/169 [09:26<00:00,  3.35s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:22<00:00,  2.76s/it]
#                    all        236       1129      0.931      0.877      0.936      0.642
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/40         0G        1.1     0.7347      1.089         50        480: 100%|██████████| 169/169 [09:36<00:00,  3.41s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:22<00:00,  2.77s/it]
#                    all        236       1129       0.93       0.89      0.934      0.647
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/40         0G       1.09      0.724      1.085         45        480: 100%|██████████| 169/169 [09:29<00:00,  3.37s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.72s/it]
#                    all        236       1129      0.931      0.882      0.929      0.636
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/40         0G      1.081     0.7137      1.079         50        480: 100%|██████████| 169/169 [09:27<00:00,  3.36s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:20<00:00,  2.60s/it]
#                    all        236       1129       0.94      0.894      0.938      0.653
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/40         0G      1.069      0.708       1.08         59        480: 100%|██████████| 169/169 [09:30<00:00,  3.37s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:20<00:00,  2.61s/it]
#                    all        236       1129      0.937      0.892      0.935      0.652
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/40         0G      1.056     0.6927      1.067         43        480: 100%|██████████| 169/169 [09:35<00:00,  3.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.64s/it]
#                    all        236       1129      0.926      0.886      0.933      0.653
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/40         0G      1.065     0.6897      1.076         49        480: 100%|██████████| 169/169 [09:28<00:00,  3.36s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.70s/it]
#                    all        236       1129      0.944      0.892      0.942       0.66
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/40         0G      1.042     0.6718      1.062         61        480: 100%|██████████| 169/169 [09:17<00:00,  3.30s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:20<00:00,  2.62s/it]
#                    all        236       1129      0.943      0.897      0.942      0.659
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/40         0G      1.034     0.6688      1.062         32        480: 100%|██████████| 169/169 [09:29<00:00,  3.37s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.63s/it]
#                    all        236       1129      0.915      0.903      0.938      0.659
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/40         0G      1.004     0.5974      1.057         44        480: 100%|██████████| 169/169 [09:19<00:00,  3.31s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:20<00:00,  2.60s/it]
#                    all        236       1129       0.94      0.909      0.944      0.663
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/40         0G     0.9788      0.579      1.047         44        480: 100%|██████████| 169/169 [09:23<00:00,  3.33s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.70s/it]
#                    all        236       1129      0.941      0.894      0.942      0.667
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/40         0G     0.9663     0.5692      1.043         24        480: 100%|██████████| 169/169 [09:23<00:00,  3.34s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.74s/it]
#                    all        236       1129      0.922      0.906       0.94      0.666
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/40         0G     0.9556     0.5565      1.038         45        480: 100%|██████████| 169/169 [09:39<00:00,  3.43s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:22<00:00,  2.80s/it]
#                    all        236       1129      0.948      0.909      0.947       0.68
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/40         0G     0.9425     0.5468      1.033         29        480: 100%|██████████| 169/169 [09:42<00:00,  3.44s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:20<00:00,  2.62s/it]
#                    all        236       1129      0.944      0.905      0.942      0.677
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/40         0G     0.9298     0.5432      1.026         20        480: 100%|██████████| 169/169 [09:40<00:00,  3.44s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:23<00:00,  2.94s/it]
#                    all        236       1129      0.939      0.901      0.942      0.679
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/40         0G     0.9134     0.5315      1.018         33        480: 100%|██████████| 169/169 [09:49<00:00,  3.49s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.66s/it]
#                    all        236       1129      0.936      0.899      0.941      0.685
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/40         0G     0.9044     0.5276      1.013         46        480: 100%|██████████| 169/169 [10:04<00:00,  3.57s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.67s/it]
#                    all        236       1129      0.935      0.907      0.943      0.678
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/40         0G      0.896     0.5204      1.015         22        480: 100%|██████████| 169/169 [09:49<00:00,  3.49s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.72s/it]
#                    all        236       1129      0.938      0.906      0.941      0.684
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/40         0G     0.8908     0.5169      1.007         21        480: 100%|██████████| 169/169 [09:49<00:00,  3.49s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.72s/it]
#                    all        236       1129       0.93      0.904      0.941      0.687
# 40 epochs completed in 6.714 hours.
# Optimizer stripped from runs/detect/train2/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train2/weights/best.pt, 6.2MB
#
# Validating runs/detect/train2/weights/best.pt...
# Ultralytics YOLOv8.0.227 🚀 Python-3.9.18 torch-1.13.1 CPU (Apple M1)
# Model summary (fused): 168 layers, 3009158 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:22<00:00,  2.78s/it]
#                    all        236       1129      0.931      0.904      0.941      0.688
#                 FRI-am        236         39      0.895      0.923       0.91      0.698
#                 FRI-pm        236         39      0.971      0.949      0.951      0.737
#                  Hands        236        261      0.931      0.866      0.948       0.55
#                 MON-am        236         39      0.968      0.974      0.969      0.779
#                 MON-pm        236         39      0.967          1      0.995       0.69
#                   Open        236         82       0.78      0.585      0.725      0.358
#                   Pill        236        158      0.806      0.886      0.908      0.626
#                PillBox        236         82      0.969      0.829      0.939      0.656
#                 SAT-am        236         39      0.898      0.904      0.899      0.726
#                 SAT-pm        236         39      0.902      0.897      0.935      0.738
#                 SUN-am        236         37      0.918      0.907      0.977      0.696
#                 SUN-pm        236         41      0.946      0.858      0.962      0.732
#                 THU-am        236         44      0.938      0.932      0.974      0.671
#                 THU-pm        236         39      0.989      0.949      0.951      0.739
#                 TUE-am        236         34          1      0.938      0.977      0.783
#                 TUE-pm        236         39      0.942      0.949      0.972      0.737
#                 WED-am        236         39      0.977      0.974      0.977      0.754
#                 WED-pm        236         39      0.958      0.949      0.975      0.705
# Speed: 0.7ms preprocess, 88.7ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to runs/detect/train2

# %%
from ultralytics import YOLO
import os

# Load the trained YOLOv8 model
model = YOLO('runs/detect/train/weights/best.pt')  # Path to your trained model

# Path to the test images
test_images_path = '/Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images'

# Get all test images
test_images = [os.path.join(test_images_path, img) for img in os.listdir(test_images_path) if img.endswith(('.png', '.jpg', '.jpeg'))]

# Run inference on the test set
results = model.predict(test_images, save=True, save_txt=True, save_conf=True, save_crop=False)

# Print results
for result in results:
    print(f"Image: {result.path}")
    print(f"Predictions: {result.boxes}")

# Results will be saved in the 'runs' directory

# %%
import cv2  # OpenCV library for computer vision tasks
from ultralytics import YOLO  # YOLO model for object detection
from PIL import Image, ImageTk  # PIL for image processing and integration with Tkinter
import tkinter as tk  # Tkinter for GUI
import socket  # Socket for network communication
import threading  # Threading for concurrent operations
import time  # Time for handling time-related operations

# Load the trained YOLOv8 model
try:
    model = YOLO('runs/detect/train/weights/best.pt')
except Exception as e:
    print(f"Error loading model: {e}")
    exit()

# Define the class names
class_names = ['FRI-am', 'FRI-pm', 'Hands', 'MON-am', 'MON-pm', 'Open', 'Pill', 'PillBox', 'SAT-am', 'SAT-pm', 'SUN-am', 'SUN-pm', 'THU-am', 'THU-pm', 'TUE-am', 'TUE-pm', 'WED-am', 'WED-pm']

# Define colors for each class visualization
class_colors = {
    'FRI-am': (0, 255, 255),
    'FRI-pm': (255, 255, 0),
    'Hands': (0, 255, 0),
    'MON-am': (255, 0, 255),
    'MON-pm': (0, 255, 255),
    'Open': (255, 255, 0),
    'Pill': (255, 0, 0),
    'PillBox': (0, 255, 255),
    'SAT-am': (255, 165, 0),
    'SAT-pm': (255, 69, 0),
    'SUN-am': (128, 0, 128),
    'SUN-pm': (75, 0, 130),
    'THU-am': (0, 255, 255),
    'THU-pm': (0, 128, 128),
    'TUE-am': (255, 0, 255),
    'TUE-pm': (128, 0, 0),
    'WED-am': (0, 0, 255),
    'WED-pm': (0, 128, 0)
}

# Server address and port for Raspberry Pi
server_address = ('192.168.168.167', 1441)  # Change this to your Raspberry Pi IP and port

# Global vars for use in methods/threads
client_socket = None
receive_thread = None
shutdown_flag = threading.Event()
last_notification_time = 0
notification_interval = 1
current_day_time = None

def setup_socket_client():
    global client_socket, receive_thread
    client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)  # Create a socket instance
    client_socket.connect(server_address)  # Connect to specified server
    print("Connected to server")

# Start a thread to handle incoming messages
    receive_thread = threading.Thread(target=receive_messages, args=(client_socket, shutdown_flag))
    receive_thread.start()

def receive_messages(sock, shutdown_flag):
    global current_day_time
    sock.settimeout(1)  # Set a timeout on the socket so we can check shutdown_flag.is_set in the loop, instead of blocking
    try:
        while not shutdown_flag.is_set():  # As long as ctrl+c is not pressed
            try:
                data = sock.recv(1024)  # Try to receive 1024 bytes of data (maximum amount; can be less)
                if not data:  # When no data is received, try again (and shutdown flag is checked again)
                    break
                current_day_time = data.decode()
                print("Received from server:", current_day_time)  # Print the received data, or do something with it
            except socket.timeout:  # When no data comes within timeout, try again
                continue
    except Exception as e:
        if not shutdown_flag.is_set():
            print(f"Connection error: {e}")
    finally:
        sock.close()

def request_date_time():
    global client_socket
    try:
        client_socket.sendall("Request date and time".encode())
    except Exception as e:
        print(f"Failed to request date and time: {e}")

# Function to draw bounding boxes with different colors
def draw_bounding_boxes(image, results): #image, which is the image/frame to be annotated, and results, which is the detection results from the YOLO model.
    global last_notification_time, current_day_time #global to indicate that it will modify the global variables 
    boxes = results[0].boxes.xyxy.cpu().numpy()
    confs = results[0].boxes.conf.cpu().numpy()
    classes = results[0].boxes.cls.cpu().numpy() #It extracts the bounding box coordinates, confidence scores, and class indices from the detection results and converts them to numpy arrays for easier manipulation.
    
    pillbox_detected = False
    compartment_open_detected = False
    wrong_compartment_opened = False
    

    #Iterates over the detected boxes. For each box
    for i, box in enumerate(boxes):
        x1, y1, x2, y2 = map(int, box) #Extracts the coordinates (x1, y1, x2, y2) and converts them to integers
        conf = confs[i]  #Retrieves the confidence score conf and class index cls
        cls = int(classes[i])  #Maps the class index to the corresponding class name label.
        label = class_names[cls]
        
        # Get color for the class
        color = class_colors.get(label, (0, 0, 255))  # Default to blue if not found
        
        # Draw bounding box and label
        cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)
        cv2.putText(image, f'{label} {confs[i]:.2f}', (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)
        
        # Check if PillBox is detected
        if label == 'PillBox':
            pillbox_detected = True

        # Check if compartment is opened
        if label == 'Open':
            compartment_open_detected = True
            
        # Check if the compartment corresponds to the current day and time
        if pillbox_detected and compartment_open_detected:
            if current_day_time and label not in current_day_time:
                wrong_compartment_opened = True
            
        if wrong_compartment_opened:
            # Add logic to trigger buzzer notification
            send_buzzer_notification()

def send_buzzer_notification():
    global client_socket
    try:
        client_socket.sendall("Wrong pill detected".encode())
    except Exception as e:
        print(f"Failed to send buzzer notification: {e}")

# AI part
def process_frame(frame):
    # Perform inference with the YOLOv8 model
    try:
        results = model(frame)
    except Exception as e:
        print(f"Error performing inference: {e}")
        return frame

    # Annotate the frame with detection results
    draw_bounding_boxes(frame, results)

    return frame

# Tkinter GUI part
def update_frame():
    ret, frame = cap.read()
    if ret:
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Convert colorspace from BGR to RGB
        frame = process_frame(frame) #Calls process_frame(frame) to perform object detection and annotation on the frame.
        img = Image.fromarray(frame)  #Converts the processed frame (which is a numpy array) to a PIL Image object using Image.fromarray.
        imgtk = ImageTk.PhotoImage(image=img) #Converts the PIL Image to a format suitable for displaying in a Tkinter GUI using ImageTk.PhotoImage.
        label_img.imgtk = imgtk #Updates the image displayed in the Tkinter Label widget (label_img) with the new frame by setting its image attribute to imgtk.
        label_img.configure(image=imgtk)
    else:
        print("Error reading frame from webcam")
    label_img.after(10, update_frame)  # Schedule the update after 10 milliseconds

# Initialize the webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Setup Tkinter window
window = tk.Tk()
window.title("Pill Detection")
window.geometry("800x600")

# Create a label to display the webcam feed
label_img = tk.Label(window)
label_img.pack()

# Start the socket client
setup_socket_client()

# Request the initial date and time
request_date_time()

# Start the webcam feed update
update_frame()

# Start the Tkinter event loop
window.mainloop()

# Release the webcam
cap.release()
# Out:
# [ WARN:0@7.668] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_f6tvh9615u/croot/opencv-suite_1691620375715/work/modules/videoio/src/cap_gstreamer.cpp (862) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# Connected to server
# Received from server: Tue-AM
# Received from server: Tue-AM
#
# 0: 288x480 1 PillBox, 1 SUN-am, 93.8ms
# Speed: 9.6ms preprocess, 93.8ms inference, 15.8ms postprocess per image at shape (1, 3, 288, 480)
# [W NNPACK.cpp:53] Could not initialize NNPACK! Reason: Unsupported hardware.
# 0: 288x480 1 PillBox, 49.6ms
# Speed: 1.2ms preprocess, 49.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 56.4ms
# Speed: 1.1ms preprocess, 56.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 48.3ms
# Speed: 1.5ms preprocess, 48.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 MON-pm, 1 PillBox, 64.6ms
# Speed: 1.2ms preprocess, 64.6ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 43.7ms
# Speed: 1.2ms preprocess, 43.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 42.3ms
# Speed: 1.3ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 41.5ms
# Speed: 1.1ms preprocess, 41.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 45.8ms
# Speed: 2.4ms preprocess, 45.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 42.5ms
# Speed: 1.3ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 75.3ms
# Speed: 1.4ms preprocess, 75.3ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 43.9ms
# Speed: 1.3ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 44.6ms
# Speed: 1.2ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 41.4ms
# Speed: 1.1ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 42.6ms
# Speed: 1.2ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 39.7ms
# Speed: 1.2ms preprocess, 39.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 41.9ms
# Speed: 1.4ms preprocess, 41.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 39.9ms
# Speed: 1.1ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 46.1ms
# Speed: 1.1ms preprocess, 46.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 MON-am, 1 PillBox, 1 SUN-am, 40.9ms
# Speed: 1.0ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 47.1ms
# Speed: 1.2ms preprocess, 47.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 40.4ms
# Speed: 1.2ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 39.9ms
# Speed: 1.3ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 40.8ms
# Speed: 1.1ms preprocess, 40.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 45.7ms
# Speed: 1.4ms preprocess, 45.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 45.4ms
# Speed: 1.5ms preprocess, 45.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 48.2ms
# Speed: 1.3ms preprocess, 48.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 56.5ms
# Speed: 2.3ms preprocess, 56.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 41.4ms
# Speed: 1.1ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 40.1ms
# Speed: 1.3ms preprocess, 40.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 47.9ms
# Speed: 1.3ms preprocess, 47.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 49.2ms
# Speed: 1.8ms preprocess, 49.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 44.2ms
# Speed: 1.4ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 39.4ms
# Speed: 1.1ms preprocess, 39.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 51.6ms
# Speed: 1.1ms preprocess, 51.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 47.0ms
# Speed: 1.5ms preprocess, 47.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 46.5ms
# Speed: 1.5ms preprocess, 46.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 39.0ms
# Speed: 1.2ms preprocess, 39.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 44.9ms
# Speed: 1.2ms preprocess, 44.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 44.1ms
# Speed: 1.3ms preprocess, 44.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 45.7ms
# Speed: 1.8ms preprocess, 45.7ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 48.7ms
# Speed: 1.1ms preprocess, 48.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 52.2ms
# Speed: 1.3ms preprocess, 52.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 MON-am, 1 PillBox, 1 SUN-am, 1 TUE-am, 47.0ms
# Speed: 1.3ms preprocess, 47.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 43.8ms
# Speed: 1.1ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 44.9ms
# Speed: 1.2ms preprocess, 44.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 MON-am, 1 PillBox, 66.2ms
# Speed: 1.1ms preprocess, 66.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 86.1ms
# Speed: 1.4ms preprocess, 86.1ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 45.2ms
# Speed: 1.7ms preprocess, 45.2ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 68.5ms
# Speed: 1.1ms preprocess, 68.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 40.4ms
# Speed: 1.2ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 45.8ms
# Speed: 1.2ms preprocess, 45.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 39.3ms
# Speed: 1.2ms preprocess, 39.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 163.9ms
# Speed: 22.1ms preprocess, 163.9ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 113.5ms
# Speed: 21.6ms preprocess, 113.5ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 49.5ms
# Speed: 1.5ms preprocess, 49.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 150.8ms
# Speed: 8.7ms preprocess, 150.8ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 78.0ms
# Speed: 11.4ms preprocess, 78.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 56.0ms
# Speed: 6.3ms preprocess, 56.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 55.5ms
# Speed: 10.9ms preprocess, 55.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 MON-pm, 1 PillBox, 1 SUN-am, 127.7ms
# Speed: 21.9ms preprocess, 127.7ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 MON-am, 1 PillBox, 1 SUN-am, 208.5ms
# Speed: 23.5ms preprocess, 208.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 167.9ms
# Speed: 1.1ms preprocess, 167.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 60.7ms
# Speed: 1.3ms preprocess, 60.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 352.9ms
# Speed: 23.9ms preprocess, 352.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 54.3ms
# Speed: 2.7ms preprocess, 54.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 72.1ms
# Speed: 3.2ms preprocess, 72.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 57.7ms
# Speed: 3.4ms preprocess, 57.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 88.0ms
# Speed: 9.8ms preprocess, 88.0ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 MON-am, 1 PillBox, 1 SUN-am, 1 TUE-am, 55.2ms
# Speed: 12.2ms preprocess, 55.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 48.6ms
# Speed: 1.4ms preprocess, 48.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 46.2ms
# Speed: 1.1ms preprocess, 46.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 57.7ms
# Speed: 1.0ms preprocess, 57.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 46.9ms
# Speed: 1.1ms preprocess, 46.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 49.2ms
# Speed: 1.1ms preprocess, 49.2ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 48.6ms
# Speed: 1.1ms preprocess, 48.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 45.9ms
# Speed: 0.9ms preprocess, 45.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 45.1ms
# Speed: 1.3ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 57.6ms
# Speed: 3.4ms preprocess, 57.6ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 45.2ms
# Speed: 1.4ms preprocess, 45.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 MON-am, 1 PillBox, 41.4ms
# Speed: 1.0ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 44.4ms
# Speed: 1.3ms preprocess, 44.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 41.1ms
# Speed: 1.2ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 43.0ms
# Speed: 1.4ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 47.8ms
# Speed: 1.0ms preprocess, 47.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 77.7ms
# Speed: 15.7ms preprocess, 77.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 43.5ms
# Speed: 4.5ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 40.0ms
# Speed: 1.3ms preprocess, 40.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 66.9ms
# Speed: 1.0ms preprocess, 66.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 41.1ms
# Speed: 1.3ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 44.6ms
# Speed: 1.4ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 46.2ms
# Speed: 1.0ms preprocess, 46.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 44.2ms
# Speed: 1.3ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 54.6ms
# Speed: 1.1ms preprocess, 54.6ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 41.9ms
# Speed: 1.1ms preprocess, 41.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 67.8ms
# Speed: 11.7ms preprocess, 67.8ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 51.5ms
# Speed: 1.2ms preprocess, 51.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 72.2ms
# Speed: 1.2ms preprocess, 72.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 88.5ms
# Speed: 2.3ms preprocess, 88.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 44.9ms
# Speed: 1.1ms preprocess, 44.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 40.5ms
# Speed: 1.2ms preprocess, 40.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 38.7ms
# Speed: 1.3ms preprocess, 38.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 39.5ms
# Speed: 1.6ms preprocess, 39.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 45.2ms
# Speed: 1.1ms preprocess, 45.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 38.3ms
# Speed: 1.7ms preprocess, 38.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 38.2ms
# Speed: 1.3ms preprocess, 38.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 42.5ms
# Speed: 1.3ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 40.3ms
# Speed: 1.2ms preprocess, 40.3ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 40.1ms
# Speed: 1.2ms preprocess, 40.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 39.9ms
# Speed: 1.0ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 88.3ms
# Speed: 1.1ms preprocess, 88.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 38.3ms
# Speed: 1.2ms preprocess, 38.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 51.9ms
# Speed: 1.1ms preprocess, 51.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 83.1ms
# Speed: 31.6ms preprocess, 83.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 82.4ms
# Speed: 10.7ms preprocess, 82.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 94.8ms
# Speed: 11.1ms preprocess, 94.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 81.9ms
# Speed: 10.8ms preprocess, 81.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 38.1ms
# Speed: 1.1ms preprocess, 38.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 37.5ms
# Speed: 4.8ms preprocess, 37.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 55.8ms
# Speed: 1.9ms preprocess, 55.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 47.6ms
# Speed: 10.9ms preprocess, 47.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 38.3ms
# Speed: 1.2ms preprocess, 38.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 40.0ms
# Speed: 1.4ms preprocess, 40.0ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 51.5ms
# Speed: 1.2ms preprocess, 51.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 85.7ms
# Speed: 10.4ms preprocess, 85.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 50.2ms
# Speed: 2.1ms preprocess, 50.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 39.3ms
# Speed: 1.1ms preprocess, 39.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 38.7ms
# Speed: 1.1ms preprocess, 38.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 37.4ms
# Speed: 1.3ms preprocess, 37.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 42.8ms
# Speed: 1.2ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 38.4ms
# Speed: 1.2ms preprocess, 38.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 38.2ms
# Speed: 1.3ms preprocess, 38.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 41.6ms
# Speed: 1.3ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 39.3ms
# Speed: 1.1ms preprocess, 39.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 46.6ms
# Speed: 3.1ms preprocess, 46.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 1 SUN-am, 39.6ms
# Speed: 1.4ms preprocess, 39.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 MON-am, 1 MON-pm, 1 Open, 1 PillBox, 1 SUN-am, 1 TUE-am, 48.4ms
# Speed: 1.2ms preprocess, 48.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 MON-am, 1 MON-pm, 2 Opens, 1 PillBox, 1 SUN-am, 1 TUE-am, 37.9ms
# Speed: 1.1ms preprocess, 37.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 1 SUN-am, 1 TUE-am, 38.6ms
# Speed: 1.1ms preprocess, 38.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 1 SUN-am, 1 THU-am, 1 TUE-am, 1 TUE-pm, 52.8ms
# Speed: 1.4ms preprocess, 52.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 MON-pm, 1 SAT-am, 1 SUN-am, 46.8ms
# Speed: 1.3ms preprocess, 46.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 1 SUN-am, 38.6ms
# Speed: 1.1ms preprocess, 38.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 1 SUN-am, 38.3ms
# Speed: 1.2ms preprocess, 38.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 38.5ms
# Speed: 1.1ms preprocess, 38.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 43.3ms
# Speed: 1.0ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 42.5ms
# Speed: 3.0ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 40.9ms
# Speed: 1.1ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 43.1ms
# Speed: 1.5ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 39.6ms
# Speed: 1.3ms preprocess, 39.6ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 74.2ms
# Speed: 1.5ms preprocess, 74.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 41.7ms
# Speed: 2.4ms preprocess, 41.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 51.3ms
# Speed: 1.0ms preprocess, 51.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 38.7ms
# Speed: 1.0ms preprocess, 38.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Received from server: Tue-AM
# Received from server: Tue-AM
#
# 0: 288x480 2 Opens, 1 PillBox, 39.9ms
# Speed: 1.0ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 38.5ms
# Speed: 1.5ms preprocess, 38.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 37.8ms
# Speed: 1.1ms preprocess, 37.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 39.6ms
# Speed: 1.3ms preprocess, 39.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 38.7ms
# Speed: 1.2ms preprocess, 38.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 39.3ms
# Speed: 1.4ms preprocess, 39.3ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 43.1ms
# Speed: 1.3ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 37.7ms
# Speed: 1.1ms preprocess, 37.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 37.9ms
# Speed: 1.2ms preprocess, 37.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 37.8ms
# Speed: 1.1ms preprocess, 37.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 37.6ms
# Speed: 1.2ms preprocess, 37.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 75.4ms
# Speed: 1.3ms preprocess, 75.4ms inference, 11.4ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 103.1ms
# Speed: 10.7ms preprocess, 103.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 80.1ms
# Speed: 11.0ms preprocess, 80.1ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 93.3ms
# Speed: 11.4ms preprocess, 93.3ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 59.9ms
# Speed: 3.0ms preprocess, 59.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 58.0ms
# Speed: 4.6ms preprocess, 58.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Received from server: Tue-AM
# Received from server: Tue-AM
#
# 0: 288x480 2 Opens, 1 PillBox, 57.4ms
# Speed: 10.9ms preprocess, 57.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 41.8ms
# Speed: 1.2ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 38.1ms
# Speed: 1.4ms preprocess, 38.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 42.3ms
# Speed: 6.2ms preprocess, 42.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 38.8ms
# Speed: 1.2ms preprocess, 38.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 48.6ms
# Speed: 1.2ms preprocess, 48.6ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 43.6ms
# Speed: 1.1ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 38.8ms
# Speed: 1.2ms preprocess, 38.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 54.4ms
# Speed: 1.1ms preprocess, 54.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 39.8ms
# Speed: 1.3ms preprocess, 39.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 38.2ms
# Speed: 1.3ms preprocess, 38.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 39.7ms
# Speed: 1.4ms preprocess, 39.7ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 39.4ms
# Speed: 1.1ms preprocess, 39.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 44.0ms
# Speed: 1.3ms preprocess, 44.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 38.6ms
# Speed: 1.0ms preprocess, 38.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 48.9ms
# Speed: 1.4ms preprocess, 48.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Received from server: Tue-AM
# Received from server: Tue-AM

# %%
import cv2
import os
import time
from PIL import Image, ImageTk
from tkinter import Tk, Button, Label, filedialog

class CaptureApp:
    def __init__(self, window):
        self.window = window
        self.window.title("Pill Detection Setup")
        self.window.geometry("800x600")

        self.label_img = Label(window)
        self.label_img.pack()

        self.capture_button = Button(window, text="Capture Image", command=self.capture_image)
        self.capture_button.pack()

        self.load_button = Button(window, text="Load Image", command=self.load_image)
        self.load_button.pack()

        self.save_button = Button(window, text="Save Image", command=self.save_image)
        self.save_button.pack()

        self.image = None

    def capture_image(self):
        cap = cv2.VideoCapture(0)
        ret, frame = cap.read()
        if ret:
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            self.image = Image.fromarray(frame)
            imgtk = ImageTk.PhotoImage(image=self.image)
            self.label_img.imgtk = imgtk
            self.label_img.configure(image=imgtk)
        cap.release()

    def load_image(self):
        file_path = filedialog.askopenfilename()
        if file_path:
            self.image = Image.open(file_path)
            imgtk = ImageTk.PhotoImage(image=self.image)
            self.label_img.imgtk = imgtk
            self.label_img.configure(image=imgtk)

    def preprocess_image(self, image):
        image = image.resize((640, 640))
        return image

    def save_image(self):
        if self.image:
            preprocessed_image = self.preprocess_image(self.image)
            save_dir = "training_data"
            if not os.path.exists(save_dir):
                os.makedirs(save_dir)
            image_path = os.path.join(save_dir, f"pill_{int(time.time())}.jpg")
            preprocessed_image.save(image_path)
            print(f"Image saved to {image_path}")
        else:
            print("No image to save")

# Start the Tkinter application
def start_app():
    root = Tk()
    app = CaptureApp(root)
    root.mainloop()

# Run the app (this will not display correctly in Jupyter Notebook, but will work as a standalone script)
start_app()

# %%
import cv2  # OpenCV library for computer vision tasks
from ultralytics import YOLO  # YOLO model for object detection
from PIL import Image, ImageTk  # PIL for image processing and integration with Tkinter
import tkinter as tk  # Tkinter for GUI
import socket  # Socket for network communication
import threading  # Threading for concurrent operations
import time  # Time for handling time-related operations

# Load the trained YOLOv8 model
try:
    model = YOLO('runs/detect/train/weights/best.pt')
except Exception as e:
    print(f"Error loading model: {e}")
    exit()

# Define the class names
class_names = ['FRI-am', 'FRI-pm', 'Hands', 'MON-am', 'MON-pm', 'Open', 'Pill', 'PillBox', 'SAT-am', 'SAT-pm', 'SUN-am', 'SUN-pm', 'THU-am', 'THU-pm', 'TUE-am', 'TUE-pm', 'WED-am', 'WED-pm']

# Define colors for each class visualization
class_colors = {
    'FRI-am': (0, 255, 255),
    'FRI-pm': (255, 255, 0),
    'Hands': (0, 255, 0),
    'MON-am': (255, 0, 255),
    'MON-pm': (0, 255, 255),
    'Open': (255, 255, 0),
    'Pill': (255, 0, 0),
    'PillBox': (0, 255, 255),
    'SAT-am': (255, 165, 0),
    'SAT-pm': (255, 69, 0),
    'SUN-am': (128, 0, 128),
    'SUN-pm': (75, 0, 130),
    'THU-am': (0, 255, 255),
    'THU-pm': (0, 128, 128),
    'TUE-am': (255, 0, 255),
    'TUE-pm': (128, 0, 0),
    'WED-am': (0, 0, 255),
    'WED-pm': (0, 128, 0)
}

# Server address and port for Raspberry Pi
server_address = ('192.168.168.167', 1443)  # Change this to your Raspberry Pi IP and port

# Global vars for use in methods/threads
client_socket = None
receive_thread = None
shutdown_flag = threading.Event()
last_notification_time = 0
notification_interval = 1
current_day_time = None

def setup_socket_client():
    global client_socket, receive_thread
    client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)  # Create a socket instance
    client_socket.connect(server_address)  # Connect to specified server
    print("Connected to server")

    # Start a thread to handle incoming messages
    receive_thread = threading.Thread(target=receive_messages, args=(client_socket, shutdown_flag))
    receive_thread.start()

def receive_messages(sock, shutdown_flag):
    global current_day_time
    sock.settimeout(1)  # Set a timeout on the socket so we can check shutdown_flag.is_set in the loop, instead of blocking
    try:
        while not shutdown_flag.is_set():  # As long as ctrl+c is not pressed
            try:
                data = sock.recv(1024)  # Try to receive 1024 bytes of data (maximum amount; can be less)
                if not data:  # When no data is received, try again (and shutdown flag is checked again)
                    break
                current_day_time = data.decode()
                print("Received from server:", current_day_time)  # Print the received data, or do something with it
            except socket.timeout:  # When no data comes within timeout, try again
                continue
    except Exception as e:
        if not shutdown_flag.is_set():
            print(f"Connection error: {e}")
    finally:
        sock.close()

def request_date_time():
    global client_socket
    try:
        client_socket.sendall("Request date and time".encode())
    except Exception as e:
        print(f"Failed to request date and time: {e}")

# Function to draw bounding boxes with different colors
def draw_bounding_boxes(image, results):
    global last_notification_time, current_day_time
    boxes = results[0].boxes.xyxy.cpu().numpy()
    confs = results[0].boxes.conf.cpu().numpy()
    classes = results[0].boxes.cls.cpu().numpy()
    
    pillbox_detected = False
    compartment_open_detected = False
    wrong_compartment_opened = False

    for i, box in enumerate(boxes):
        x1, y1, x2, y2 = map(int, box)
        conf = confs[i]
        cls = int(classes[i])
        label = class_names[cls]
        
        color = class_colors.get(label, (0, 0, 255))  # Default to blue if not found
        
        cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)
        cv2.putText(image, f'{label} {confs[i]:.2f}', (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)
        
        if label == 'PillBox':
            pillbox_detected = True

        if label == 'Open':
            compartment_open_detected = True
            
            # Check if the open compartment matches the expected compartment
            if current_day_time and label not in current_day_time:
                wrong_compartment_opened = True

        # Debug statements to verify logic
        print(f"Label: {label}")
        print(f"Current Day and Time: {current_day_time}")
        print(f"Pillbox Detected: {pillbox_detected}")
        print(f"Compartment Open Detected: {compartment_open_detected}")
        print(f"Wrong Compartment Opened: {wrong_compartment_opened}")

    if pillbox_detected and compartment_open_detected and wrong_compartment_opened:
        send_buzzer_notification()

def send_buzzer_notification():
    global client_socket
    try:
        client_socket.sendall("Wrong pill detected".encode())
    except Exception as e:
        print(f"Failed to send buzzer notification: {e}")

# AI part
def process_frame(frame):
    # Perform inference with the YOLOv8 model
    try:
        results = model(frame)
    except Exception as e:
        print(f"Error performing inference: {e}")
        return frame

    # Annotate the frame with detection results
    draw_bounding_boxes(frame, results)

    return frame

# Tkinter GUI part
def update_frame():
    ret, frame = cap.read()
    if ret:
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Convert colorspace from BGR to RGB
        frame = process_frame(frame) #Calls process_frame(frame) to perform object detection and annotation on the frame.
        img = Image.fromarray(frame)  #Converts the processed frame (which is a numpy array) to a PIL Image object using Image.fromarray.
        imgtk = ImageTk.PhotoImage(image=img) #Converts the PIL Image to a format suitable for displaying in a Tkinter GUI using ImageTk.PhotoImage.
        label_img.imgtk = imgtk #Updates the image displayed in the Tkinter Label widget (label_img) with the new frame by setting its image attribute to imgtk.
        label_img.configure(image=imgtk)
    else:
        print("Error reading frame from webcam")
    label_img.after(10, update_frame)  # Schedule the update after 10 milliseconds

# Initialize the webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Setup Tkinter window
window = tk.Tk()
window.title("Pill Detection")
window.geometry("800x600")

# Create a label to display the webcam feed
label_img = tk.Label(window)
label_img.pack()

# Start the socket client
setup_socket_client()

# Request the initial date and time
request_date_time()

# Start the webcam feed update
update_frame()

# Start the Tkinter event loop
window.mainloop()

# Release the webcam
cap.release()
# Out:
# [ WARN:0@1.396] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_f6tvh9615u/croot/opencv-suite_1691620375715/work/modules/videoio/src/cap_gstreamer.cpp (862) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# Connected to server
# Received from server: Tue-PMTue-PM
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 SAT-am, 1 SAT-pm, 2 THU-ams, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 92.8ms
# Speed: 7.3ms preprocess, 92.8ms inference, 9.2ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# [W NNPACK.cpp:53] Could not initialize NNPACK! Reason: Unsupported hardware.
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 2 SAT-ams, 1 SAT-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 2 WED-ams, 1 WED-pm, 55.3ms
# Speed: 1.3ms preprocess, 55.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 2 SAT-ams, 1 SAT-pm, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 WED-am, 1 WED-pm, 50.3ms
# Speed: 1.1ms preprocess, 50.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 2 SAT-ams, 1 SAT-pm, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 54.2ms
# Speed: 1.3ms preprocess, 54.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 2 FRI-pms, 1 MON-am, 2 SAT-ams, 1 SAT-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 WED-am, 1 WED-pm, 60.3ms
# Speed: 1.2ms preprocess, 60.3ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 2 SAT-ams, 1 SAT-pm, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 WED-am, 1 WED-pm, 47.5ms
# Speed: 1.4ms preprocess, 47.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 SAT-am, 1 SAT-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 WED-am, 1 WED-pm, 73.6ms
# Speed: 1.4ms preprocess, 73.6ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 SAT-am, 1 SAT-pm, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 WED-am, 1 WED-pm, 81.7ms
# Speed: 1.3ms preprocess, 81.7ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 2 SAT-ams, 1 SAT-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 WED-am, 1 WED-pm, 102.3ms
# Speed: 1.6ms preprocess, 102.3ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 2 FRI-pms, 1 Open, 2 SAT-ams, 1 SAT-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 WED-am, 1 WED-pm, 92.2ms
# Speed: 1.6ms preprocess, 92.2ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: Open
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 1 FRI-am, 2 FRI-pms, 1 MON-am, 2 SAT-ams, 1 SAT-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 WED-am, 1 WED-pm, 91.4ms
# Speed: 1.5ms preprocess, 91.4ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 2 SAT-ams, 1 SAT-pm, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 66.2ms
# Speed: 1.3ms preprocess, 66.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 2 SAT-ams, 1 SAT-pm, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 WED-am, 1 WED-pm, 114.1ms
# Speed: 1.1ms preprocess, 114.1ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 2 FRI-pms, 1 MON-am, 1 SAT-am, 1 SAT-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 WED-am, 1 WED-pm, 41.7ms
# Speed: 1.3ms preprocess, 41.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 2 SAT-ams, 1 SAT-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 48.1ms
# Speed: 1.2ms preprocess, 48.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 2 SAT-ams, 1 SAT-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 WED-am, 1 WED-pm, 44.2ms
# Speed: 1.2ms preprocess, 44.2ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 Open, 1 SAT-am, 1 SAT-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 45.9ms
# Speed: 1.3ms preprocess, 45.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: Open
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 2 SAT-ams, 1 SAT-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 48.6ms
# Speed: 1.3ms preprocess, 48.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 SAT-am, 1 SAT-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 WED-am, 1 WED-pm, 44.5ms
# Speed: 1.1ms preprocess, 44.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 SAT-am, 1 SAT-pm, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 47.6ms
# Speed: 1.2ms preprocess, 47.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 2 SAT-ams, 1 SAT-pm, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 42.8ms
# Speed: 1.2ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 SAT-am, 1 SAT-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 WED-am, 1 WED-pm, 56.9ms
# Speed: 1.3ms preprocess, 56.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 SAT-am, 1 SAT-pm, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 WED-am, 1 WED-pm, 43.4ms
# Speed: 1.1ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 2 FRI-pms, 1 MON-am, 2 SAT-ams, 1 SAT-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 WED-am, 1 WED-pm, 44.8ms
# Speed: 1.3ms preprocess, 44.8ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 Open, 1 SAT-am, 1 SAT-pm, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 44.2ms
# Speed: 1.2ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# ...
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 2 FRI-pms, 1 MON-am, 1 MON-pm, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 2 THU-pms, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 113.0ms
# Speed: 1.3ms preprocess, 113.0ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 SAT-am, 1 SAT-pm, 1 SUN-am, 1 SUN-pm, 1 THU-am, 2 THU-pms, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 131.2ms
# Speed: 2.4ms preprocess, 131.2ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 SAT-am, 1 SAT-pm, 1 SUN-am, 1 SUN-pm, 1 THU-am, 2 THU-pms, 1 TUE-am, 1 TUE-pm, 1 WED-am, 2 WED-pms, 157.7ms
# Speed: 2.2ms preprocess, 157.7ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 SAT-am, 1 SAT-pm, 1 SUN-am, 1 SUN-pm, 1 THU-am, 2 THU-pms, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 114.3ms
# Speed: 2.3ms preprocess, 114.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 SAT-am, 1 SAT-pm, 1 SUN-am, 1 SUN-pm, 1 THU-am, 2 THU-pms, 1 TUE-am, 1 TUE-pm, 2 WED-ams, 1 WED-pm, 47.3ms
# Speed: 1.3ms preprocess, 47.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
#
# 0: 288x480 1 FRI-am, 2 FRI-pms, 1 MON-am, 1 MON-pm, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 2 THU-pms, 1 TUE-am, 1 TUE-pm, 2 WED-ams, 1 WED-pm, 42.1ms
# Speed: 1.4ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: SAT-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: THU-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SUN-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: TUE-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: FRI-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: WED-am
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: MON-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Label: SAT-pm
# Current Day and Time: Tue-PMTue-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False

# %%
import cv2  # OpenCV library for computer vision tasks
from ultralytics import YOLO  # YOLO model for object detection
from PIL import Image, ImageTk  # PIL for image processing and integration with Tkinter
import tkinter as tk  # Tkinter for GUI
import socket  # Socket for network communication
import threading  # Threading for concurrent operations
import time  # Time for handling time-related operations
import logging  # For logging configurations
import sys  # For redirecting standard output
import os  # For setting environment variables
import contextlib  # For suppressing print statements

# Suppress logging from specific libraries
logging.getLogger('ultralytics').setLevel(logging.ERROR)
logging.getLogger('torch').setLevel(logging.ERROR)
logging.getLogger('PIL').setLevel(logging.ERROR)

# Suppress OpenCV debug prints using environment variable
os.environ['OPENCV_LOG_LEVEL'] = 'ERROR'

# Context manager to suppress print statements
@contextlib.contextmanager
def suppress_stdout():
    with open(os.devnull, 'w') as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout

# Load the trained YOLOv8 model
try:
    with suppress_stdout():
        model = YOLO('runs/detect/train/weights/best.pt')
except Exception as e:
    print(f"Error loading model: {e}")
    exit()

# Define the class names
class_names = ['FRI-am', 'FRI-pm', 'Hands', 'MON-am', 'MON-pm', 'Open', 'Pill', 'PillBox', 'SAT-am', 'SAT-pm', 'SUN-am', 'SUN-pm', 'THU-am', 'THU-pm', 'TUE-am', 'TUE-pm', 'WED-am', 'WED-pm']

# Define the day and time slots for the pillbox compartments
day_time_slots = ['MON-am', 'MON-pm', 'TUE-am', 'TUE-pm', 'WED-am', 'WED-pm', 'THU-am', 'THU-pm', 'FRI-am', 'FRI-pm', 'SAT-am', 'SAT-pm', 'SUN-am', 'SUN-pm']

# Define colors for each class visualization
class_colors = {
    'FRI-am': (0, 255, 255),
    'FRI-pm': (255, 255, 0),
    'Hands': (0, 255, 0),
    'MON-am': (255, 0, 255),
    'MON-pm': (0, 255, 255),
    'Open': (255, 255, 0),
    'Pill': (255, 0, 0),
    'PillBox': (0, 255, 255),
    'SAT-am': (255, 165, 0),
    'SAT-pm': (255, 69, 0),
    'SUN-am': (128, 0, 128),
    'SUN-pm': (75, 0, 130),
    'THU-am': (0, 255, 255),
    'THU-pm': (0, 128, 128),
    'TUE-am': (255, 0, 255),
    'TUE-pm': (128, 0, 0),
    'WED-am': (0, 0, 255),
    'WED-pm': (0, 128, 0)
}

# Server address and port for Raspberry Pi
server_address = ('192.168.168.167', 1443)  # Change this to your Raspberry Pi IP and port

# Global vars for use in methods/threads
client_socket = None
receive_thread = None
shutdown_flag = threading.Event()
last_debug_time = time.time()
debug_interval = 2
current_day_time = None

def setup_socket_client():
    global client_socket, receive_thread
    client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)  # Create a socket instance
    client_socket.connect(server_address)  # Connect to specified server
    print("Connected to server")

    # Start a thread to handle incoming messages
    receive_thread = threading.Thread(target=receive_messages, args=(client_socket, shutdown_flag))
    receive_thread.start()

def receive_messages(sock, shutdown_flag):
    global current_day_time
    sock.settimeout(1)  # Set a timeout on the socket so we can check shutdown_flag.is_set in the loop, instead of blocking
    try:
        while not shutdown_flag.is_set():  # As long as ctrl+c is not pressed
            try:
                data = sock.recv(1024)  # Try to receive 1024 bytes of data (maximum amount; can be less)
                if not data:  # When no data is received, try again (and shutdown flag is checked again)
                    break
                current_day_time = data.decode()
                print("Received from server:", current_day_time)  # Print the received data, or do something with it
            except socket.timeout:  # When no data comes within timeout, try again
                continue
    except Exception as e:
        if not shutdown_flag.is_set():
            print(f"Connection error: {e}")
    finally:
        sock.close()

def request_date_time():
    global client_socket
    try:
        client_socket.sendall("Request date and time".encode())
    except Exception as e:
        print(f"Failed to request date and time: {e}")

# Function to draw bounding boxes with different colors
def draw_bounding_boxes(image, results):
    global last_debug_time, current_day_time
    boxes = results[0].boxes.xyxy.cpu().numpy()
    confs = results[0].boxes.conf.cpu().numpy()
    classes = results[0].boxes.cls.cpu().numpy()
    
    pillbox_detected = False
    compartment_open_detected = False
    wrong_compartment_opened = False
    detected_labels = []  # Initialize an empty list to store detected labels

    for i, box in enumerate(boxes):
        x1, y1, x2, y2 = map(int, box)
        conf = confs[i]
        cls = int(classes[i])
        label = class_names[cls]
        if label in day_time_slots:
            detected_labels.append(label)  # Append the detected label to the list

        color = class_colors.get(label, (0, 0, 255))  # Default to blue if not found
        
        cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)
        cv2.putText(image, f'{label} {confs[i]:.2f}', (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)
        
        if label == 'PillBox':
            pillbox_detected = True

        if label == 'Open':
            compartment_open_detected = True
            
        # # Check if the open compartment matches the expected compartment
        # if label == ' Open' and current_day_time not in:
        #     print(f"Expected: {current_day_time}, Detected: {label}")
        #     wrong_compartment_opened = True

    missing_labels = find_missing_labels(day_time_slots, detected_labels)
            
    if compartment_open_detected == True:
        if current_day_time not in missing_labels:
            wrong_compartment_opened = True
        else :
            wrong_compartment_opened = False

        
    # Check if it's time to print debug statements
    if last_debug_time + debug_interval < time.time():
        # Debug statements to verify logic
        print(f"Current Day and Time: {current_day_time}")
        print(f"Pillbox Detected: {pillbox_detected}")
        print(f"Compartment Open Detected: {compartment_open_detected}")
        print(f"Wrong Compartment Opened: {wrong_compartment_opened}")
        print(f"Detected Labels: {detected_labels}")
        print(f"Missing Labels: {missing_labels}")
        # Update the last debug time
        last_debug_time = time.time()


    if (compartment_open_detected == True and wrong_compartment_opened == True and len(detected_labels) >= 10):
        send_buzzer_notification()

def find_missing_labels(day_time_slots, detected_labels):
    """
    Find the labels that are present in one list but not in the other.
    
    Args:
        day_time_slots (list): List of labels representing day and time slots.
        detected_labels (list): List of labels detected in the current frame.
    
    Returns:
        list: List of labels that are present in one list but not in the other.
    """
    missing_labels = []
    for label in day_time_slots:
        if label not in detected_labels:
            missing_labels.append(label)
    for label in detected_labels:
        if label not in day_time_slots:
            missing_labels.append(label)
    return missing_labels


def send_buzzer_notification():
    global client_socket
    try:
        client_socket.sendall("Wrong pill detected".encode())
    except Exception as e:
        print(f"Failed to send buzzer notification: {e}")

# AI part
def process_frame(frame):
    # Perform inference with the YOLOv8 model
    try:
        with suppress_stdout():
            results = model(frame)
    except Exception as e:
        print(f"Error performing inference: {e}")
        return frame

    # Annotate the frame with detection results
    draw_bounding_boxes(frame, results)

    return frame

# Tkinter GUI part
def update_frame():
    ret, frame = cap.read()
    if ret:
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Convert colorspace from BGR to RGB
        frame = process_frame(frame)  # Calls process_frame(frame) to perform object detection and annotation on the frame.
        img = Image.fromarray(frame)  # Converts the processed frame (which is a numpy array) to a PIL Image object using Image.fromarray.
        imgtk = ImageTk.PhotoImage(image=img)  # Converts the PIL Image to a format suitable for displaying in a Tkinter GUI using ImageTk.PhotoImage.
        label_img.imgtk = imgtk  # Updates the image displayed in the Tkinter Label widget (label_img) with the new frame by setting its image attribute to imgtk.
        label_img.configure(image=imgtk)
    else:
        print("Error reading frame from webcam")
    label_img.after(10, update_frame)  # Schedule the update after 10 milliseconds

# Initialize the webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Setup Tkinter window
window = tk.Tk()
window.title("Pill Detection")
window.geometry("800x600")

# Create a label to display the webcam feed
label_img = tk.Label(window)
label_img.pack()

# Start the socket client
setup_socket_client()

# Request the initial date and time
request_date_time()

# Start the webcam feed update
update_frame()

# Start the Tkinter event loop
window.mainloop()

# Release the webcam
cap.release()
# Out:
# [ WARN:0@102.365] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_f6tvh9615u/croot/opencv-suite_1691620375715/work/modules/videoio/src/cap_gstreamer.cpp (862) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# Connected to server
# Received from server: Wed-PM
# Received from server: Wed-PM
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-am', 'MON-am', 'MON-pm', 'TUE-am', 'SAT-am', 'WED-pm', 'SAT-pm', 'FRI-pm', 'THU-am', 'SUN-pm', 'FRI-am', 'SUN-am', 'TUE-am', 'THU-pm', 'TUE-pm', 'WED-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-am', 'MON-am', 'SAT-am', 'TUE-am', 'MON-pm', 'WED-pm', 'SAT-pm', 'THU-am', 'FRI-am', 'SUN-am', 'SUN-pm', 'FRI-pm', 'TUE-am', 'THU-pm', 'TUE-pm', 'WED-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-am', 'MON-am', 'MON-pm', 'TUE-am', 'SAT-am', 'WED-pm', 'SAT-pm', 'FRI-am', 'SUN-pm', 'SUN-am', 'FRI-pm', 'THU-am', 'TUE-am', 'THU-pm', 'TUE-pm', 'FRI-am', 'WED-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-am', 'MON-am', 'TUE-am', 'SAT-am', 'MON-pm', 'WED-pm', 'SAT-pm', 'THU-am', 'SUN-am', 'FRI-am', 'SUN-pm', 'FRI-pm', 'TUE-am', 'TUE-pm', 'THU-pm', 'WED-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-am', 'MON-am', 'TUE-am', 'MON-pm', 'SAT-am', 'WED-pm', 'SAT-pm', 'SUN-pm', 'SUN-am', 'FRI-am', 'THU-am', 'TUE-am', 'TUE-pm', 'FRI-pm', 'THU-pm', 'WED-pm', 'FRI-am']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-am', 'MON-am', 'SAT-am', 'TUE-am', 'SAT-pm', 'MON-pm', 'WED-pm', 'FRI-am', 'SUN-pm', 'SUN-am', 'FRI-pm', 'TUE-am', 'THU-am', 'TUE-pm', 'FRI-am']
# Missing Labels: ['THU-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-am', 'MON-am', 'TUE-am', 'MON-pm', 'SAT-am', 'WED-pm', 'SAT-pm', 'SUN-am', 'SUN-pm', 'FRI-pm', 'TUE-am', 'FRI-am', 'THU-am', 'TUE-pm', 'THU-pm', 'WED-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-am', 'MON-am', 'MON-pm', 'TUE-am', 'SAT-am', 'WED-pm', 'SAT-pm', 'SUN-pm', 'SUN-am', 'FRI-am', 'THU-am', 'FRI-pm', 'TUE-am', 'TUE-pm', 'THU-pm', 'FRI-am']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-am', 'MON-am', 'TUE-am', 'SAT-am', 'MON-pm', 'SAT-pm', 'FRI-am', 'WED-pm', 'THU-am', 'SUN-am', 'FRI-pm', 'SUN-pm', 'TUE-am', 'TUE-pm', 'THU-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-am', 'MON-am', 'SAT-am', 'MON-pm', 'TUE-am', 'WED-pm', 'FRI-am', 'SAT-pm', 'THU-am', 'SUN-am', 'SUN-pm', 'FRI-pm', 'TUE-am', 'THU-pm', 'TUE-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-am', 'MON-am', 'SAT-am', 'TUE-am', 'MON-pm', 'SAT-pm', 'WED-pm', 'FRI-am', 'SUN-pm', 'SUN-am', 'FRI-pm', 'TUE-am', 'THU-am', 'THU-pm', 'TUE-pm', 'FRI-am']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-am', 'MON-am', 'SAT-am', 'TUE-am', 'WED-pm', 'MON-pm', 'SAT-pm', 'SUN-pm', 'THU-am', 'FRI-am', 'FRI-pm', 'SUN-am', 'TUE-am', 'TUE-pm', 'WED-pm', 'THU-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-am', 'MON-am', 'SAT-am', 'TUE-am', 'MON-pm', 'SAT-pm', 'WED-pm', 'FRI-am', 'SUN-am', 'SUN-pm', 'THU-am', 'FRI-pm', 'TUE-pm', 'TUE-am', 'THU-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-am', 'MON-am', 'MON-pm', 'TUE-am', 'SAT-am', 'WED-pm', 'SAT-pm', 'SUN-pm', 'FRI-am', 'FRI-pm', 'SUN-am', 'THU-am', 'TUE-am', 'TUE-pm', 'THU-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-am', 'MON-am', 'MON-pm', 'SAT-am', 'TUE-am', 'WED-pm', 'SAT-pm', 'SUN-pm', 'THU-pm', 'FRI-am', 'THU-am', 'FRI-pm', 'SUN-am', 'TUE-pm', 'TUE-am']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-am', 'MON-am', 'SAT-am', 'TUE-am', 'MON-pm', 'WED-pm', 'SAT-pm', 'FRI-am', 'SUN-am', 'SUN-pm', 'THU-am', 'FRI-pm', 'THU-pm', 'TUE-am', 'SAT-am', 'TUE-pm', 'FRI-am', 'WED-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-am', 'MON-am', 'SAT-am', 'TUE-am', 'MON-pm', 'SAT-pm', 'WED-pm', 'FRI-am', 'THU-am', 'SUN-am', 'SUN-pm', 'FRI-pm', 'THU-pm', 'TUE-am', 'TUE-pm', 'WED-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: []
# Missing Labels: ['MON-am', 'MON-pm', 'TUE-am', 'TUE-pm', 'WED-am', 'WED-pm', 'THU-am', 'THU-pm', 'FRI-am', 'FRI-pm', 'SAT-am', 'SAT-pm', 'SUN-am', 'SUN-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: []
# Missing Labels: ['MON-am', 'MON-pm', 'TUE-am', 'TUE-pm', 'WED-am', 'WED-pm', 'THU-am', 'THU-pm', 'FRI-am', 'FRI-pm', 'SAT-am', 'SAT-pm', 'SUN-am', 'SUN-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['MON-am', 'TUE-am', 'SUN-pm', 'SUN-am', 'MON-pm', 'FRI-am', 'WED-am', 'FRI-am', 'WED-am', 'SAT-am']
# Missing Labels: ['TUE-pm', 'WED-pm', 'THU-am', 'THU-pm', 'FRI-pm', 'SAT-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['MON-am', 'TUE-am', 'SUN-am', 'MON-pm', 'SUN-pm', 'WED-am', 'FRI-am', 'FRI-am', 'THU-pm', 'SAT-am', 'WED-am']
# Missing Labels: ['TUE-pm', 'WED-pm', 'THU-am', 'FRI-pm', 'SAT-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['MON-am', 'TUE-am', 'SUN-pm', 'MON-pm', 'SUN-am', 'WED-am', 'THU-pm', 'FRI-am', 'FRI-am']
# Missing Labels: ['TUE-pm', 'WED-pm', 'THU-am', 'FRI-pm', 'SAT-am', 'SAT-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['MON-am', 'FRI-am', 'WED-am', 'SUN-am', 'SAT-pm', 'SAT-am', 'SAT-am', 'SUN-pm', 'TUE-am', 'FRI-am', 'MON-pm']
# Missing Labels: ['TUE-pm', 'WED-pm', 'THU-am', 'THU-pm', 'FRI-pm']
# Received from server: Wed-PM
# Received from server: Wed-PM
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-am', 'MON-am', 'FRI-am', 'TUE-am', 'SAT-pm', 'SUN-am', 'SUN-pm', 'SAT-am', 'THU-am', 'SAT-am', 'MON-pm', 'TUE-pm', 'FRI-am', 'WED-pm', 'THU-pm', 'FRI-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-am', 'MON-am', 'FRI-am', 'TUE-am', 'SAT-pm', 'SUN-pm', 'SUN-am', 'SAT-am', 'MON-pm', 'SAT-am', 'THU-am', 'TUE-pm', 'FRI-am', 'WED-pm', 'THU-pm', 'FRI-pm', 'WED-am']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-am', 'MON-am', 'FRI-am', 'SAT-am', 'TUE-am', 'SUN-pm', 'SAT-pm', 'SUN-am', 'FRI-am', 'SAT-am', 'MON-pm', 'TUE-pm', 'WED-pm', 'THU-am']
# Missing Labels: ['THU-pm', 'FRI-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['WED-am', 'MON-am', 'FRI-am', 'TUE-am', 'SAT-am', 'SAT-pm', 'SUN-am', 'SUN-pm', 'SAT-am', 'MON-pm', 'FRI-am', 'THU-am', 'TUE-pm']
# Missing Labels: ['WED-pm', 'THU-pm', 'FRI-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['WED-am', 'MON-am', 'TUE-am', 'SAT-pm', 'FRI-am', 'SUN-pm', 'SUN-am', 'MON-pm', 'SAT-am', 'SAT-am', 'FRI-pm', 'THU-pm', 'TUE-pm', 'THU-am', 'FRI-am']
# Missing Labels: ['WED-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['WED-am', 'MON-am', 'FRI-am', 'TUE-am', 'SAT-pm', 'SUN-pm', 'SUN-am', 'SAT-am', 'SAT-am', 'FRI-am', 'MON-pm', 'WED-am']
# Missing Labels: ['TUE-pm', 'WED-pm', 'THU-am', 'THU-pm', 'FRI-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['WED-am', 'MON-am', 'FRI-am', 'TUE-am', 'SAT-am', 'SUN-am', 'SUN-pm', 'SAT-pm', 'SAT-am', 'FRI-am', 'MON-pm', 'THU-am']
# Missing Labels: ['TUE-pm', 'WED-pm', 'THU-pm', 'FRI-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['WED-am', 'MON-am', 'FRI-am', 'TUE-am', 'SAT-pm', 'SAT-am', 'SUN-am', 'SUN-pm', 'SAT-am', 'THU-am', 'MON-pm', 'FRI-am', 'FRI-pm', 'TUE-pm']
# Missing Labels: ['WED-pm', 'THU-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['WED-am', 'MON-am', 'FRI-am', 'SUN-am', 'SAT-pm', 'TUE-am', 'SUN-pm', 'SAT-am', 'SAT-am', 'FRI-am', 'THU-am', 'MON-pm']
# Missing Labels: ['TUE-pm', 'WED-pm', 'THU-pm', 'FRI-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: []
# Missing Labels: ['MON-am', 'MON-pm', 'TUE-am', 'TUE-pm', 'WED-am', 'WED-pm', 'THU-am', 'THU-pm', 'FRI-am', 'FRI-pm', 'SAT-am', 'SAT-pm', 'SUN-am', 'SUN-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am', 'SUN-pm', 'FRI-am', 'WED-am', 'SUN-am', 'SAT-pm', 'THU-am']
# Missing Labels: ['TUE-pm', 'WED-pm', 'THU-pm', 'FRI-pm', 'SAT-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am', 'SUN-pm', 'WED-am', 'FRI-am', 'SAT-pm', 'THU-am', 'SUN-am', 'TUE-pm', 'TUE-am', 'SAT-am', 'WED-pm']
# Missing Labels: ['THU-pm', 'FRI-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['MON-pm', 'SUN-pm', 'TUE-am', 'MON-am', 'SUN-am', 'WED-am', 'FRI-am', 'SAT-pm', 'TUE-pm']
# Missing Labels: ['WED-pm', 'THU-am', 'THU-pm', 'FRI-pm', 'SAT-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: []
# Missing Labels: ['MON-am', 'MON-pm', 'TUE-am', 'TUE-pm', 'WED-am', 'WED-pm', 'THU-am', 'THU-pm', 'FRI-am', 'FRI-pm', 'SAT-am', 'SAT-pm', 'SUN-am', 'SUN-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['FRI-am', 'SAT-am', 'SUN-am', 'TUE-am', 'MON-am', 'SUN-pm', 'WED-am', 'MON-pm', 'FRI-am']
# Missing Labels: ['TUE-pm', 'WED-pm', 'THU-am', 'THU-pm', 'FRI-pm', 'SAT-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['MON-am', 'SUN-am', 'FRI-am', 'WED-am', 'TUE-am', 'SUN-pm', 'SAT-am', 'MON-pm', 'THU-am', 'THU-pm', 'TUE-pm', 'FRI-am', 'SAT-pm']
# Missing Labels: ['WED-pm', 'FRI-pm']
# Received from server: Wed-PM
# Received from server: Wed-PM
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['FRI-am', 'MON-am', 'SUN-am', 'SAT-am', 'WED-am', 'TUE-am', 'SUN-pm', 'MON-pm', 'THU-am', 'THU-pm', 'TUE-pm', 'FRI-am', 'TUE-am']
# Missing Labels: ['WED-pm', 'FRI-pm', 'SAT-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: []
# Missing Labels: ['MON-am', 'MON-pm', 'TUE-am', 'TUE-pm', 'WED-am', 'WED-pm', 'THU-am', 'THU-pm', 'FRI-am', 'FRI-pm', 'SAT-am', 'SAT-pm', 'SUN-am', 'SUN-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['FRI-am', 'SAT-am', 'MON-am', 'WED-am', 'TUE-am', 'FRI-pm', 'THU-am', 'SUN-am', 'SAT-pm', 'SUN-pm', 'MON-pm', 'THU-pm', 'WED-pm', 'TUE-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['FRI-am', 'SAT-am', 'WED-am', 'MON-am', 'TUE-am', 'THU-am', 'SUN-am', 'FRI-pm', 'SUN-pm', 'SAT-pm', 'WED-pm', 'MON-pm', 'THU-pm', 'TUE-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['FRI-am', 'SAT-am', 'WED-am', 'MON-am', 'THU-am', 'TUE-am', 'FRI-pm', 'SAT-pm', 'SUN-am', 'SUN-pm', 'WED-pm', 'THU-pm', 'MON-pm']
# Missing Labels: ['TUE-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['FRI-am', 'SAT-am', 'WED-am', 'TUE-am', 'MON-am', 'SUN-pm', 'SUN-am', 'THU-am', 'FRI-am']
# Missing Labels: ['MON-pm', 'TUE-pm', 'WED-pm', 'THU-pm', 'FRI-pm', 'SAT-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: []
# Missing Labels: ['MON-am', 'MON-pm', 'TUE-am', 'TUE-pm', 'WED-am', 'WED-pm', 'THU-am', 'THU-pm', 'FRI-am', 'FRI-pm', 'SAT-am', 'SAT-pm', 'SUN-am', 'SUN-pm']
# Received from server: Wed-PM
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: []
# Missing Labels: ['MON-am', 'MON-pm', 'TUE-am', 'TUE-pm', 'WED-am', 'WED-pm', 'THU-am', 'THU-pm', 'FRI-am', 'FRI-pm', 'SAT-am', 'SAT-pm', 'SUN-am', 'SUN-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: []
# Missing Labels: ['MON-am', 'MON-pm', 'TUE-am', 'TUE-pm', 'WED-am', 'WED-pm', 'THU-am', 'THU-pm', 'FRI-am', 'FRI-pm', 'SAT-am', 'SAT-pm', 'SUN-am', 'SUN-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['FRI-am', 'TUE-am', 'SAT-am', 'MON-pm', 'MON-am', 'FRI-pm', 'SUN-pm', 'TUE-pm', 'SAT-pm', 'WED-am', 'THU-am', 'SUN-am', 'THU-pm', 'WED-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['FRI-am', 'MON-am', 'TUE-am', 'SAT-am', 'MON-pm', 'FRI-pm', 'SAT-pm', 'SUN-pm', 'WED-am', 'THU-am', 'SUN-am', 'TUE-pm', 'THU-pm']
# Missing Labels: ['WED-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['FRI-am', 'SAT-am', 'TUE-am', 'WED-am', 'MON-am', 'MON-pm', 'THU-am', 'SUN-pm', 'SUN-am', 'FRI-pm', 'SAT-pm', 'TUE-pm', 'THU-pm', 'WED-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['FRI-am', 'SAT-am', 'TUE-am', 'FRI-pm', 'MON-am', 'MON-pm', 'SAT-pm', 'SUN-pm', 'THU-am', 'WED-am', 'SUN-am', 'THU-pm', 'TUE-pm', 'WED-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['FRI-am', 'TUE-am', 'SAT-am', 'MON-am', 'FRI-pm', 'SAT-pm', 'SUN-pm', 'SUN-am', 'MON-pm', 'WED-am', 'THU-am', 'THU-pm', 'TUE-pm']
# Missing Labels: ['WED-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['FRI-am', 'TUE-am', 'SAT-am', 'SUN-pm', 'MON-am', 'SAT-pm', 'MON-pm', 'WED-am', 'SUN-am', 'THU-am', 'FRI-pm', 'TUE-pm', 'THU-pm']
# Missing Labels: ['WED-pm']
# Received from server: Wed-PM
# Received from server: Wed-PM
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['FRI-am', 'SAT-am', 'TUE-am', 'MON-am', 'SUN-pm', 'FRI-pm', 'MON-pm', 'SUN-am', 'SAT-pm', 'WED-am', 'THU-am', 'THU-pm', 'TUE-pm']
# Missing Labels: ['WED-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['FRI-am', 'TUE-am', 'SAT-am', 'FRI-pm', 'MON-am', 'SUN-pm', 'MON-pm', 'SAT-pm', 'THU-am', 'TUE-pm', 'SUN-am', 'WED-am', 'THU-pm', 'WED-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['FRI-am', 'TUE-am', 'SAT-am', 'FRI-pm', 'MON-pm', 'MON-am', 'SAT-pm', 'SUN-pm', 'THU-am', 'WED-am', 'TUE-pm', 'SUN-am', 'THU-pm', 'WED-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['FRI-am', 'TUE-am', 'SAT-am', 'MON-am', 'SUN-pm', 'MON-pm', 'FRI-pm', 'SAT-pm', 'WED-am', 'TUE-pm', 'THU-am', 'THU-pm', 'SUN-am']
# Missing Labels: ['WED-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['FRI-am', 'TUE-am', 'MON-am', 'SAT-am', 'FRI-pm', 'MON-pm', 'WED-am', 'SUN-pm', 'SAT-pm', 'SUN-am', 'THU-am', 'THU-pm', 'TUE-pm', 'WED-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['FRI-am', 'TUE-am', 'MON-pm', 'MON-am', 'FRI-pm', 'SAT-am', 'SUN-pm', 'THU-am', 'SAT-pm', 'WED-am', 'SUN-am', 'THU-pm', 'TUE-pm', 'WED-pm']
# Missing Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Detected Labels: ['FRI-am', 'TUE-am', 'SAT-am', 'MON-am', 'FRI-pm', 'WED-am', 'MON-pm', 'THU-am', 'SUN-pm', 'SUN-am', 'SAT-pm', 'TUE-pm', 'THU-pm', 'WED-pm']
# Missing Labels: []
# Received from server: Wed-PM
# Received from server: Wed-PM
# Received from server: Wed-PM
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
