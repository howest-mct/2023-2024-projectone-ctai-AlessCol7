# %%
import yaml
import os

with open('data.yaml', 'r') as file:
    data = yaml.safe_load(file)

print("Train path:", os.path.exists(data['train']))
print("Validation path:", os.path.exists(data['val']))
print("Test path:", os.path.exists(data['test']))

def count_images(directory):
    supported_formats = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.tif')
    return len([name for name in os.listdir(directory) if name.lower().endswith(supported_formats)])

print(f" The number of images in training set: {count_images(data['train'])}")
print(f" The number of images in validation set: {count_images(data['val'])}")
print(f" The number of images in test set: {count_images(data['test'])}")
# Out:
# Train path: True
# Validation path: True
# Test path: True
#  The number of images in training set: 1642
#  The number of images in validation set: 227
#  The number of images in test set: 112

# %%
from ultralytics import YOLO
from pathlib import Path

absolute_from_relative_path = Path('data.yaml').resolve()

model = YOLO('yolov8n.pt')  # Load a pretrained model (recommended for training)
results = model.train(data=absolute_from_relative_path, epochs=20, imgsz=480)
# Out:
# New https://pypi.org/project/ultralytics/8.2.28 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.227 🚀 Python-3.9.18 torch-1.13.1 CPU (Apple M1)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/data.yaml, epochs=20, patience=50, batch=16, imgsz=480, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# Overriding model.yaml nc=80 with nc=18
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    754822  ultralytics.nn.modules.head.Detect           [18, [64, 128, 256]]
# Model summary: 225 layers, 3014358 parameters, 3014342 gradients
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/train/labels.cache... 1642 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1642/1642 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 618, len(boxes) = 7548. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Scanning /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/valid/labels.cache... 227 images, 0 backgrounds, 0 corrupt: 100%|██████████| 227/227 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 82, len(boxes) = 1003. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000455, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 480 train, 480 val
# Using 0 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20         0G      1.699      3.577       1.48         53        480: 100%|██████████| 103/103 [06:56<00:00,  4.04s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.74s/it]
#                    all        227       1003      0.581      0.167      0.198      0.116
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20         0G      1.518      2.086      1.339        116        480: 100%|██████████| 103/103 [07:24<00:00,  4.31s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:24<00:00,  3.11s/it]
#                    all        227       1003       0.17      0.513      0.275       0.16
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20         0G      1.459      1.787      1.301         59        480: 100%|██████████| 103/103 [06:49<00:00,  3.98s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:22<00:00,  2.76s/it]
#                    all        227       1003      0.259      0.597      0.332      0.197
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20         0G      1.421      1.657      1.265         96        480: 100%|██████████| 103/103 [06:51<00:00,  4.00s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:23<00:00,  2.95s/it]
#                    all        227       1003      0.313      0.634      0.371      0.217
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20         0G      1.407      1.543      1.257        101        480: 100%|██████████| 103/103 [06:51<00:00,  4.00s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:22<00:00,  2.76s/it]
#                    all        227       1003      0.317      0.634      0.388      0.238
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20         0G      1.359       1.48      1.251         46        480: 100%|██████████| 103/103 [06:43<00:00,  3.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:22<00:00,  2.80s/it]
#                    all        227       1003      0.339      0.727      0.439      0.263
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20         0G      1.324      1.412      1.228         68        480: 100%|██████████| 103/103 [06:51<00:00,  4.00s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:22<00:00,  2.78s/it]
#                    all        227       1003      0.375      0.694      0.515      0.318
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20         0G      1.323      1.379      1.224         58        480: 100%|██████████| 103/103 [06:51<00:00,  4.00s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.66s/it]
#                    all        227       1003      0.425      0.711      0.578      0.354
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20         0G      1.305      1.284       1.21         72        480: 100%|██████████| 103/103 [06:42<00:00,  3.91s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.67s/it]
#                    all        227       1003      0.465      0.742      0.619      0.395
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20         0G       1.27      1.238      1.195        119        480: 100%|██████████| 103/103 [06:56<00:00,  4.05s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.68s/it]
#                    all        227       1003      0.536      0.721      0.652      0.419
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20         0G      1.242      1.191      1.209         50        480: 100%|██████████| 103/103 [06:44<00:00,  3.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:23<00:00,  2.91s/it]
#                    all        227       1003      0.648      0.729      0.733      0.476
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20         0G      1.203      1.109      1.188         38        480: 100%|██████████| 103/103 [06:49<00:00,  3.97s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.74s/it]
#                    all        227       1003      0.649      0.752      0.758       0.49
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20         0G      1.185       1.04      1.179         21        480: 100%|██████████| 103/103 [06:21<00:00,  3.70s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:20<00:00,  2.62s/it]
#                    all        227       1003       0.73      0.809      0.813      0.527
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20         0G      1.164     0.9839      1.156         42        480: 100%|██████████| 103/103 [06:36<00:00,  3.85s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:22<00:00,  2.80s/it]
#                    all        227       1003      0.771      0.796       0.83       0.54
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20         0G      1.148     0.9331      1.146         42        480: 100%|██████████| 103/103 [06:35<00:00,  3.84s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:22<00:00,  2.84s/it]
#                    all        227       1003      0.816      0.821      0.855      0.556
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20         0G      1.138     0.9097      1.144         30        480: 100%|██████████| 103/103 [06:28<00:00,  3.77s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:23<00:00,  2.95s/it]
#                    all        227       1003      0.849      0.839      0.881      0.574
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20         0G      1.112     0.8795      1.127         52        480: 100%|██████████| 103/103 [06:38<00:00,  3.87s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:20<00:00,  2.61s/it]
#                    all        227       1003      0.862      0.802      0.884      0.583
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20         0G       1.08     0.8436      1.108         29        480: 100%|██████████| 103/103 [06:35<00:00,  3.84s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:20<00:00,  2.60s/it]
#                    all        227       1003      0.856      0.839      0.897      0.594
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20         0G      1.078     0.8212      1.107         61        480: 100%|██████████| 103/103 [06:29<00:00,  3.79s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:22<00:00,  2.80s/it]
#                    all        227       1003      0.917      0.859      0.918      0.611
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20         0G      1.052     0.8034      1.099         37        480: 100%|██████████| 103/103 [06:36<00:00,  3.85s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:21<00:00,  2.63s/it]
#                    all        227       1003      0.896      0.865      0.914      0.615
# 20 epochs completed in 2.375 hours.
# Optimizer stripped from runs/detect/train2/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train2/weights/best.pt, 6.2MB
#
# Validating runs/detect/train2/weights/best.pt...
# Ultralytics YOLOv8.0.227 🚀 Python-3.9.18 torch-1.13.1 CPU (Apple M1)
# Model summary (fused): 168 layers, 3009158 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:27<00:00,  3.43s/it]
#                    all        227       1003      0.896      0.864      0.914      0.615
#                 FRI-am        227         30          1      0.925      0.938      0.684
#                 FRI-pm        227         30      0.842      0.886       0.96      0.663
#                  Hands        227        261      0.891      0.876      0.956      0.562
#                 MON-am        227         30      0.938        0.9      0.959      0.706
#                 MON-pm        227         30      0.936      0.979      0.983      0.644
#                   Open        227         82      0.867      0.557      0.692       0.35
#                   Pill        227        158      0.791      0.848      0.894      0.609
#                PillBox        227         82      0.945       0.84      0.945      0.642
#                 SAT-am        227         30      0.936        0.9      0.904      0.636
#                 SAT-pm        227         30      0.757      0.767      0.817      0.634
#                 SUN-am        227         28      0.815      0.857      0.861      0.571
#                 SUN-pm        227         32      0.932      0.875      0.962       0.63
#                 THU-am        227         35      0.969      0.893      0.969      0.597
#                 THU-pm        227         30      0.781      0.834       0.87       0.58
#                 TUE-am        227         25      0.955       0.84      0.937      0.688
#                 TUE-pm        227         30      0.817        0.9      0.926        0.6
#                 WED-am        227         30      0.965      0.928      0.912       0.63
#                 WED-pm        227         30          1      0.953      0.967      0.651
# Speed: 1.5ms preprocess, 113.6ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs/detect/train2

# %%
from ultralytics import YOLO
import os

# Load the trained YOLOv8 model
model = YOLO('runs/detect/train2/weights/best.pt')  # Path to your trained model

# Path to the test images
test_images_path = '/Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images'

# Get all test images
test_images = [os.path.join(test_images_path, img) for img in os.listdir(test_images_path) if img.endswith(('.png', '.jpg', '.jpeg'))]

# Run inference on the test set
results = model.predict(test_images, save=True, save_txt=True, save_conf=True, save_crop=False)

# Print results
for result in results:
    print(f"Image: {result.path}")
    print(f"Predictions: {result.boxes}")

# Results will be saved in the 'runs' directory
# Out:
# [W NNPACK.cpp:53] Could not initialize NNPACK! Reason: Unsupported hardware.
 480x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 2 THU-pms, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 85: 480x480 1 Pill, 86: 480x480 2 FRI-ams, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 SAT-am, 3 SAT-pms, 1 SUN-am, 1 SUN-pm, 3 THU-ams, 2 THU-pms, 1 TUE-pm, 1 WED-am, 1 WED-pm, 87: 480x480 4 Handss, 88: 480x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 SAT-am, 1 SAT-pm, 1 SUN-am, 1 SUN-pm, 2 THU-ams, 2 THU-pms, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 89: 480x480 16 Pills, 90: 480x480 1 Pill, 91: 480x480 1 Open, 1 PillBox, 92: 480x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 SAT-am, 1 SAT-pm, 1 SUN-am, 1 SUN-pm, 2 THU-ams, 1 THU-pm, 1 TUE-pm, 1 WED-am, 1 WED-pm, 93: 480x480 4 Opens, 94: 480x480 7 Handss, 95: 480x480 2 Handss, 96: 480x480 1 PillBox, 97: 480x480 2 Handss, 98: 480x480 1 Open, 1 PillBox, 99: 480x480 5 Handss, 100: 480x480 7 Handss, 101: 480x480 2 Opens, 102: 480x480 2 Pills, 103: 480x480 1 Hands, 104: 480x480 2 FRI-pms, 1 Open, 2 SAT-pms, 1 THU-pm, 1 WED-pm, 105: 480x480 2 Handss, 106: 480x480 7 Handss, 107: 480x480 4 PillBoxs, 108: 480x480 2 Pills, 109: 480x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 2 SUN-pms, 1 THU-am, 2 THU-pms, 1 TUE-am, 2 TUE-pms, 1 WED-am, 1 WED-pm, 110: 480x480 1 PillBox, 111: 480x480 3 Pills, 10284.8ms
# Speed: 2.1ms preprocess, 91.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 480)
# Results saved to runs/detect/predict2
# 112 labels saved to runs/detect/predict2/labels
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/Screenshot_20240531_092058_Chrome_jpg.rf.781e6428f262e4970964114b64111520.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6., 6.])
# conf: tensor([0.9078, 0.8300, 0.7891, 0.7861, 0.7675, 0.7238, 0.7088, 0.6758, 0.6015, 0.5957, 0.5941, 0.5642, 0.5590, 0.5378, 0.4854, 0.4703, 0.3289])
# data: tensor([[1.7749e+02, 1.6429e+02, 2.1765e+02, 1.8963e+02, 9.0775e-01, 6.0000e+00],
#         [2.5021e+02, 1.1803e+02, 2.9805e+02, 1.3979e+02, 8.2997e-01, 6.0000e+00],
#         [2.2694e+02, 1.4823e+02, 2.7262e+02, 1.7639e+02, 7.8913e-01, 6.0000e+00],
#         [1.2992e+02, 1.1263e+02, 1.7022e+02, 1.4119e+02, 7.8608e-01, 6.0000e+00],
#         [9.5387e+01, 1.4691e+02, 1.4025e+02, 1.7498e+02, 7.6747e-01, 6.0000e+00],
#         [2.5523e+02, 1.7419e+02, 3.0609e+02, 2.0040e+02, 7.2385e-01, 6.0000e+00],
#         [3.3095e+02, 3.4141e+02, 3.7299e+02, 3.6406e+02, 7.0883e-01, 6.0000e+00],
#         [2.5983e+02, 3.4025e+02, 2.9523e+02, 3.6390e+02, 6.7584e-01, 6.0000e+00],
#         [1.5355e+02, 1.9516e+02, 1.9622e+02, 2.2295e+02, 6.0151e-01, 6.0000e+00],
#         [3.5984e+02, 1.4341e+02, 4.1435e+02, 1.7367e+02, 5.9566e-01, 6.0000e+00],
#         [2.8022e+02, 1.3930e+02, 3.1961e+02, 1.6279e+02, 5.9410e-01, 6.0000e+00],
#         [359.8436, 143.4134, 414.3548, 173.6728],
#         [280.2203, 139.3020, 319.6124, 162.7851],
#         [330.5451, 128.0871, 377.1620, 151.4432],
#         [203.2827, 126.3190, 239.0486, 152.0158],
#         [276.1215,  85.4920, 314.6121, 110.7914],
#         [405.0666, 336.4948, 446.8801, 367.2172],
#         [121.4186, 177.9742, 167.9023, 204.8323],
#         [280.1600, 417.6882, 306.3567, 431.7391]])
# xyxyn: tensor([[0.3698, 0.3423, 0.4534, 0.3951],
#         [0.5213, 0.2459, 0.6209, 0.2912],
#         [0.4728, 0.3088, 0.5680, 0.3675],
#         [0.2707, 0.2347, 0.3546, 0.2941],
#         [0.1987, 0.3061, 0.2922, 0.3645],
#         [0.5317, 0.3629, 0.6377, 0.4175],
#         [0.6895, 0.7113, 0.7771, 0.7585],
#         [0.5413, 0.7088, 0.6151, 0.7581],
#         [0.3199, 0.4066, 0.4088, 0.4645],
#         [0.7497, 0.2988, 0.8632, 0.3618],
#         [0.5838, 0.2902, 0.6659, 0.3391],
#         [0.6886, 0.2668, 0.7858, 0.3155],
#         [0.4235, 0.2632, 0.4980, 0.3167],
#         [0.5753, 0.1781, 0.6554, 0.2308],
#         [0.8439, 0.7010, 0.9310, 0.7650],
#         [0.2530, 0.3708, 0.3498, 0.4267],
#         [0.5837, 0.8702, 0.6382, 0.8995]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/aprepitant-80-MG-13-_jpg.rf.22dd3b2a60a04bd33d9c2465b5705ccb.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.])
# conf: tensor([0.9467])
# data: tensor([[135.2202,   0.0000, 344.9607, 480.0000,   0.9467,   6.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([1, 6])
# xywh: tensor([[240.0904, 240.0000, 209.7405, 480.0000]])
# xywhn: tensor([[0.5002, 0.5000, 0.4370, 1.0000]])
# xyxy: tensor([[135.2202,   0.0000, 344.9607, 480.0000]])
# xyxyn: tensor([[0.2817, 0.0000, 0.7187, 1.0000]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/20240531_130555_jpg.rf.af69b3438569e435289ac3ccf52b2022.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([5., 5., 5., 5., 5., 5.])
# conf: tensor([0.9338, 0.9035, 0.8956, 0.8647, 0.8617, 0.5702])
# data: tensor([[187.0950, 294.5482, 227.3769, 343.8438,   0.9338,   5.0000],
#         [145.9552, 291.2771, 187.3706, 342.6776,   0.9035,   5.0000],
#         [336.6272, 266.7910, 378.4698, 344.1326,   0.8956,   5.0000],
#         [262.9413, 268.7021, 306.3181, 342.8888,   0.8647,   5.0000],
#         [334.4934, 178.5360, 367.5906, 250.0079,   0.8617,   5.0000],
#         [263.5664, 291.6658, 307.3627, 342.3667,   0.5702,   5.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([6, 6])
# xywh: tensor([[207.2359, 319.1960,  40.2819,  49.2957],
#         [166.6629, 316.9774,  41.4153,  51.4005],
#         [357.5485, 305.4618,  41.8427,  77.3416],
#         [284.6297, 305.7955,  43.3767,  74.1866],
#         [351.0420, 214.2719,  33.0972,  71.4719],
#         [285.4645, 317.0162,  43.7963,  50.7009]])
# xywhn: tensor([[0.4317, 0.6650, 0.0839, 0.1027],
#         [0.3472, 0.6604, 0.0863, 0.1071],
#         [0.7449, 0.6364, 0.0872, 0.1611],
#         [0.5930, 0.6371, 0.0904, 0.1546],
#         [0.7313, 0.4464, 0.0690, 0.1489],
#         [0.5947, 0.6605, 0.0912, 0.1056]])
# xyxy: tensor([[187.0950, 294.5482, 227.3769, 343.8438],
#         [145.9552, 291.2771, 187.3706, 342.6776],
#         [336.6272, 266.7910, 378.4698, 344.1326],
#         [262.9413, 268.7021, 306.3181, 342.8888],
#         [334.4934, 178.5360, 367.5906, 250.0079],
#         [263.5664, 291.6658, 307.3627, 342.3667]])
# xyxyn: tensor([[0.3898, 0.6136, 0.4737, 0.7163],
#         [0.3041, 0.6068, 0.3904, 0.7139],
#         [0.7013, 0.5558, 0.7885, 0.7169],
#         [0.5478, 0.5598, 0.6382, 0.7144],
#         [0.6969, 0.3719, 0.7658, 0.5208],
#         [0.5491, 0.6076, 0.6403, 0.7133]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/carvedilol-3-125-MG-5-Copy_jpg.rf.50227a2a80eace14d269a6924ebfe514.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6., 6.])
# conf: tensor([0.9298, 0.9241])
# data: tensor([[115.9464, 226.6885, 416.2707, 454.1954,   0.9298,   6.0000],
#         [117.5476,   7.2138, 409.6896, 225.2357,   0.9241,   6.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([2, 6])
# xywh: tensor([[266.1085, 340.4420, 300.3243, 227.5069],
#         [263.6186, 116.2248, 292.1420, 218.0219]])
# xywhn: tensor([[0.5544, 0.7093, 0.6257, 0.4740],
#         [0.5492, 0.2421, 0.6086, 0.4542]])
# xyxy: tensor([[115.9464, 226.6885, 416.2707, 454.1954],
#         [117.5476,   7.2138, 409.6896, 225.2357]])
# xyxyn: tensor([[0.2416, 0.4723, 0.8672, 0.9462],
#         [0.2449, 0.0150, 0.8535, 0.4692]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/20240603_165639-1-_jpg.rf.e104cd410309da1127148ba635cad033.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6.])
# conf: tensor([0.3540])
# data: tensor([[1.2440e+02, 2.6083e+02, 2.3176e+02, 4.3403e+02, 3.5404e-01, 6.0000e+00]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([1, 6])
# xywh: tensor([[178.0825, 347.4259, 107.3625, 173.2012]])
# xywhn: tensor([[0.3710, 0.7238, 0.2237, 0.3608]])
# xyxy: tensor([[124.4013, 260.8253, 231.7637, 434.0265]])
# xyxyn: tensor([[0.2592, 0.5434, 0.4828, 0.9042]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/Screenshot_20240528_152007_Pinterest_jpg.rf.3eb8f0440cf6fe6d34dece18755607a5.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([7.])
# conf: tensor([0.8465])
# data: tensor([[ 48.3569,  77.4147, 480.0000, 283.0918,   0.8465,   7.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([1, 6])
# xywh: tensor([[264.1784, 180.2532, 431.6431, 205.6771]])
# xywhn: tensor([[0.5504, 0.3755, 0.8993, 0.4285]])
# xyxy: tensor([[ 48.3569,  77.4147, 480.0000, 283.0918]])
# xyxyn: tensor([[0.1007, 0.1613, 1.0000, 0.5898]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/Poza-din-04-06-2024-de-la-11-20-5-1-_jpg.rf.50ea4bf8fa711db60d77d5de149f46f5.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor
])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/Oseltamivir-45-MG-6-_jpg.rf.755a2091fd9eeabd66a03d888e510d9e.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6., 6.])
# conf: tensor([0.9455, 0.9440])
# data: tensor([[ 32.9211,   4.9327, 477.5428, 190.5431,   0.9455,   6.0000],
#         [ 23.9050, 184.4838, 479.3057, 400.0287,   0.9440,   6.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([2, 6])
# xywh: tensor([[255.2320,  97.7379, 444.6216, 185.6104],
#         [251.6053, 292.2562, 455.4007, 215.5449]])
# xywhn: tensor([[0.5317, 0.2036, 0.9263, 0.3867],
#         [0.5242, 0.6089, 0.9488, 0.4491]])
# xyxy: tensor([[ 32.9211,   4.9327, 477.5428, 190.5431],
#         [ 23.9050, 184.4838, 479.3057, 400.0287]])
# xyxyn: tensor([[0.0686, 0.0103, 0.9949, 0.3970],
#         [0.0498, 0.3843, 0.9986, 0.8334]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/Screenshot_20240528_150803_Pinterest_jpg.rf.0889529e31ab9be5218171909eee43d1.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2., 2., 2., 2.])
# conf: tensor([0.9069, 0.8945, 0.8543, 0.8027])
# data: tensor([[245.4312, 115.8497, 347.1501, 188.8011,   0.9069,   2.0000],
#         [339.3780,  98.8159, 434.0619, 176.0731,   0.8945,   2.0000],
#         [265.1124, 235.1739, 463.6835, 376.8286,   0.8543,   2.0000],
#         [ 71.9597, 186.8150, 196.6945, 315.8680,   0.8027,   2.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([4, 6])
# xywh: tensor([[296.2906, 152.3254, 101.7188,  72.9515],
#         [386.7199, 137.4445,  94.6839,  77.2572],
#         [364.3979, 306.0013, 198.5710, 141.6547],
#         [134.3271, 251.3415, 124.7348, 129.0529]])
# xywhn: tensor([[0.6173, 0.3173, 0.2119, 0.1520],
#         [0.8057, 0.2863, 0.1973, 0.1610],
#         [0.7592, 0.6375, 0.4137, 0.2951],
#         [0.2798, 0.5236, 0.2599, 0.2689]])
# xyxy: tensor([[245.4312, 115.8497, 347.1501, 188.8011],
#         [339.3780,  98.8159, 434.0619, 176.0731],
#         [265.1124, 235.1739, 463.6835, 376.8286],
#         [ 71.9597, 186.8150, 196.6945, 315.8680]])
# xyxyn: tensor([[0.5113, 0.2414, 0.7232, 0.3933],
#         [0.7070, 0.2059, 0.9043, 0.3668],
#         [0.5523, 0.4899, 0.9660, 0.7851],
#         [0.1499, 0.3892, 0.4098, 0.6581]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/Screenshot_20240523_094931_Pinterest_jpg.rf.6360e2b2e54ee14bd88b38b44226b8bc.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8889])
# data: tensor([[ 47.0908,  57.4570, 406.9322, 332.6829,   0.8889,   2.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([1, 6])
# xywh: tensor([[227.0115, 195.0700, 359.8414, 275.2259]])
# xywhn: tensor([[0.4729, 0.4064, 0.7497, 0.5734]])
# xyxy: tensor([[ 47.0908,  57.4570, 406.9322, 332.6829]])
# xyxyn: tensor([[0.0981, 0.1197, 0.8478, 0.6931]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/Screenshot_20240523_100054_Pinterest_jpg.rf.8a92ff4e2a379268128ca46352988fb6.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.9043])
# data: tensor([[ 35.7209,  15.3023, 446.2124, 353.8129,   0.9043,   2.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([1, 6])
# xywh: tensor([[240.9666, 184.5576, 410.4915, 338.5107]])
# xywhn: tensor([[0.5020, 0.3845, 0.8552, 0.7052]])
# xyxy: tensor([[ 35.7209,  15.3023, 446.2124, 353.8129]])
# xyxyn: tensor([[0.0744, 0.0319, 0.9296, 0.7371]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/Screenshot_20240528_150739_Pinterest_jpg.rf.98db28037e042799dc6000369bf51a4a.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2., 2., 2., 2., 2., 2.])
# conf: tensor([0.9060, 0.9049, 0.8603, 0.8461, 0.8456, 0.8348])
# data: tensor([[259.1545,  16.6482, 471.6586, 128.1492,   0.9060,   2.0000],
#         [ 18.4770,  16.2844, 226.7610, 127.5602,   0.9049,   2.0000],
#         [258.8863, 238.8884, 457.5547, 350.5934,   0.8603,   2.0000],
#         [ 22.0431, 240.4525, 221.7543, 350.2629,   0.8461,   2.0000],
#         [257.3239, 131.0684, 452.0751, 237.6434,   0.8456,   2.0000],
#         [ 19.1172, 130.4961, 214.3870, 239.3410,   0.8348,   2.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([6, 6])
# xywh: tensor([[365.4066,  72.3987, 212.5040, 111.5010],
#         [122.6190,  71.9223, 208.2840, 111.2758],
#         [358.2205, 294.7409, 198.6683, 111.7050],
#         [121.8987, 295.3577, 199.7112, 109.8104],
#         [354.6995, 184.3559, 194.7512, 106.5750],
#         [116.7521, 184.9186, 195.2698, 108.8449]])
# xywhn: tensor([[0.7613, 0.1508, 0.4427, 0.2323],
#         [0.2555, 0.1498, 0.4339, 0.2318],
#         [0.7463, 0.6140, 0.4139, 0.2327],
#         [0.2540, 0.6153, 0.4161, 0.2288],
#         [0.7390, 0.3841, 0.4057, 0.2220],
#         [0.2432, 0.3852, 0.4068, 0.2268]])
# xyxy: tensor([[259.1545,  16.6482, 471.6586, 128.1492],
#         [ 18.4770,  16.2844, 226.7610, 127.5602],
#         [258.8863, 238.8884, 457.5547, 350.5934],
#         [ 22.0431, 240.4525, 221.7543, 350.2629],
#         [257.3239, 131.0684, 452.0751, 237.6434],
#         [ 19.1172, 130.4961, 214.3870, 239.3410]])
# xyxyn: tensor([[0.5399, 0.0347, 0.9826, 0.2670],
#         [0.0385, 0.0339, 0.4724, 0.2658],
#         [0.5393, 0.4977, 0.9532, 0.7304],
#         [0.0459, 0.5009, 0.4620, 0.7297],
#         [0.5361, 0.2731, 0.9418, 0.4951],
#         [0.0398, 0.2719, 0.4466, 0.4986]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/Screenshot_20240523_100013_Pinterest_jpg.rf.991941b3808fa9249bd2f078893337ca.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8851])
# data: tensor([[ 53.1178,  85.9035, 413.5825, 300.8497,   0.8851,   2.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([1, 6])
# xywh: tensor([[233.3501, 193.3766, 360.4647, 214.9462]])
# xywhn: tensor([[0.4861, 0.4029, 0.7510, 0.4478]])
# xyxy: tensor([[ 53.1178,  85.9035, 413.5825, 300.8497]])
# xyxyn: tensor([[0.1107, 0.1790, 0.8616, 0.6268]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/pitavastatin-1-MG-11-Copy_jpg.rf.804c18270ec8d3a154ad02cdd4db59ff.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6., 6.])
# conf: tensor([0.9557, 0.9373])
# data: tensor([[250.4664,  59.3458, 478.9207, 336.1013,   0.9557,   6.0000],
#         [ 18.5267,  57.1096, 252.8393, 338.4636,   0.9373,   6.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([2, 6])
# xywh: tensor([
#         [0.3697, 0.3331, 0.5137, 0.3924],
#         [0.2935, 0.4108, 0.4448, 0.4731],
#         [0.7342, 0.8688, 0.8062, 0.9408],
#         [0.4664, 0.3803, 0.6231, 0.4408],
#         [0.0685, 0.2377, 0.2562, 0.3708],
#         [0.6393, 0.3471, 0.7785, 0.4029],
#         [0.7778, 0.3132, 0.9476, 0.3781],
#         [0.7694, 0.7344, 0.8309, 0.7715],
#         [0.4108, 0.2530, 0.6084, 0.3207],
#         [0.3717, 0.7394, 0.4634, 0.8030],
#         [0.7017, 0.7324, 0.7673, 0.7728],
#         [0.5152, 0.7327, 0.5673, 0.7727],
#         [0.2179, 0.7472, 0.3112, 0.7975],
#         [0.8737, 0.8680, 0.9578, 0.9356],
#         [0.6132, 0.2480, 0.6869, 0.2848],
#         [0.5691, 0.7314, 0.6342, 0.7734],
#         [0.5974, 0.8724, 0.6693, 0.9383],
#         [0.5121, 0.8671, 0.5976, 0.9052],
#         [0.8334, 0.7324, 0.9014, 0.7675],
#         [0.6699, 0.8717, 0.7377, 0.9390],
#         [0.5127, 0.9042, 0.5958, 0.9417],
#         [0.0696, 0.7450, 0.1494, 0.7975],
#         [0.6395, 0.7286, 0.7011, 0.7744],
#         [0.9007, 0.7347, 0.9539, 0.7692],
#         [0.2567, 0.2121, 0.4022, 0.3451]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/20240523_083222_jpg.rf.9141a62bb5b647846b42f9450d5d24d3.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([7., 5.])
# conf: tensor([0.9083, 0.8043])
# data: tensor([[ 83.3647, 161.5891, 257.3511, 303.4761,   0.9083,   7.0000],
#         [157.6193,   0.0000, 221.4158,  37.5474,   0.8043,   5.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([2, 6])
# xywh: tensor([[170.3579, 232.5326, 173.9864, 141.8870],
#         [189.5175,  18.7737,  63.7965,  37.5474]])
# xywhn: tensor([[0.3549, 0.4844, 0.3625, 0.2956],
#         [0.3948, 0.0391, 0.1329, 0.0782]])
# xyxy: tensor([[ 83.3647, 161.5891, 257.3511, 303.4761],
#         [157.6193,   0.0000, 221.4158,  37.5474]])
# xyxyn: tensor([[0.1737, 0.3366, 0.5361, 0.6322],
#         [0.3284, 0.0000, 0.4613, 0.0782]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/Screenshot_20240523_100541_Pinterest_jpg.rf.f795c5c218b86692db9deb559a52e184.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8951])
# data: tensor([[2.8757e+01, 4.3495e-01, 4.5771e+02, 1.9941e+02, 8.9507e-01, 2.0000e+00]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([1, 6])
# xywh: tensor([[243.2326,  99.9210, 428.9510, 198.9721]])
# xywhn: tensor([[0.5067, 0.2082, 0.8936, 0.4145]])
# xyxy: tensor([[2.8757e+01, 4.3495e-01, 4.5771e+02, 1.9941e+02]])
# xyxyn: tensor([[5.9911e-02, 9.0615e-04, 9.5356e-01, 4.1543e-01]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/Screenshot_20240523_094840_Pinterest_jpg.rf.6b3b6c05405ef5828f547c07bfdd1342.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2., 2.])
# conf: tensor([0.9128, 0.8962])
# data: tensor([[ 63.1860,  47.0317, 267.3133, 228.5278,   0.9128,   2.0000],
#         [254.2635,  76.6230, 432.9064, 212.2150,   0.8962,   2.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([2, 6])
# xywh: tensor([[165.2496, 137.7798, 204.1273, 181.4961],
#         [343.5849, 144.4190, 178.6429, 135.5920]])
# xywhn: tensor([[0.3443, 0.2870, 0.4253, 0.3781],
#         [0.7158, 0.3009, 0.3722, 0.2825]])
# xyxy: tensor([[ 63.1860,  47.0317, 267.3133, 228.5278],
#         [254.2635,  76.6230, 432.9064, 212.2150]])
# xyxyn: tensor([[0.1316, 0.0980, 0.5569, 0.4761],
#         [0.5297, 0.1596, 0.9019, 0.4421]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/Screenshot_20240523_095258_Pinterest_jpg.rf.8a5b9ceff5e2adacd867f3cdad37948e.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.9345])
# data: tensor([[ 73.6674,   4.7805, 459.6548, 290.9274,   0.9345,   2.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([1, 6])
# xywh: tensor([[266.6611, 147.8539, 385.9874, 286.1470]])
# xywhn: tensor([[0.5555, 0.3080, 0.8041, 0.5961]])
# xyxy: tensor([[ 73.6674,   4.7805, 459.6548, 290.9274]])
# xyxyn: tensor([[0.1535, 0.0100, 0.9576, 0.6061]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/Screenshot_20240528_150947_Pinterest_jpg.rf.c2ee92c5ffb3ea3782f6541d7aa8f511.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2., 2., 2., 2., 2., 2., 2., 2., 2., 2.])
# conf: tensor([0.9491, 0.9230, 0.8892, 0.8738, 0.8639, 0.8622, 0.8324, 0.8083, 0.7287, 0.4892])
# data: tensor([[ 47.5836, 155.1128, 130.8517, 229.7658,   0.9491,   2.0000],
#         [294.0017, 115.7380, 431.9563, 169.9448,   0.9230,   2.0000],
#         [ 82.4040, 255.2203, 238.8142, 296.9225,   0.8892,   2.0000],
#         [129.8598, 357.3197, 256.1730, 401.3284,   0.8738,   2.0000],
#         [109.3558, 294.3002, 254.3769, 354.3489,   0.8639,   2.0000],
#         [278.6594, 204.6163, 450.7482, 329.3773,   0.8622,   2.0000],
#         [ 93.2470, 109.6025, 179.7923, 187.3869,   0.8324,   2.0000],
#         [ 61.6581, 332.6721, 146.5917, 381.5422,   0.8083,   2.0000],
#         [258.3145,  85.3957, 372.1307, 125.4342,   0.7287,   2.0000],
#         [281.5396,   0.0000, 421.9654,  39.8123,   0.4892,   2.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([10, 6])
# xywh: tensor([[ 89.2177, 192.4393,  83.2681,  74.6530],
#         [362.9790, 142.8414, 137.9546,  54.2068],
#         [160.6091, 276.0714, 156.4102,  41.7021],
#         [193.0164, 379.3241, 126.3131,  44.0087],
#         [181.8664, 324.3246, 145.0211,  60.0488],
#         [364.7038, 266.9968, 172.0889, 124.7610],
#         [136.5196, 148.4947,  86.5453,  77.7843],
#         [104.1249, 357.1072,  84.9336,  48.8701],
#         [315.2226, 105.4149, 113.8162,  40.0385],
#         [351.7525,  19.9062, 140.4258,  39.8123]])
# xywhn: tensor([[0.1859, 0.4009, 0.1735, 0.1555],
#         [0.7562, 0.2976, 0.2874, 0.1129],
#         [0.3346, 0.5751, 0.3259, 0.0869],
#         [0.4021, 0.7903, 0.2632, 0.0917],
#         [0.3789, 0.6757, 0.3021, 0.1251],
#         [0.7598, 0.5562, 0.3585, 0.2599],
#         [0.2844, 0.3094, 0.1803, 0.1621],
#         [0.2169, 0.7440, 0.1769, 0.1018],
#         [0.6567, 0.2196, 0.2371, 0.0834],
#         [0.7328, 0.0415, 0.2926, 0.0829]])
# xyxy: tensor([[ 47.5836, 155.1128, 130.8517, 229.7658],
#         [294.0017, 115.7380, 431.9563, 169.9448],
#         [171.6590, 222.3870, 212.9902, 329.7786],
#         [262.8033, 105.3150, 303.8979, 214.0694],
#         [354.2293, 107.8376, 394.8330, 216.4946],
#         [127.7424, 228.5719, 167.2525, 328.7413],
#         [263.5736, 222.8082, 304.9329, 329.6612],
#         [308.0114, 108.0254, 350.8080, 218.0156],
#         [307.4624, 105.4462, 350.6045, 211.5282],
#         [402.1850, 226.1802, 440.5421, 325.9472],
#         [402.5638, 226.8328, 441.3255, 324.4617],
#         [309.8085, 225.4301, 351.5445, 331.5114],
#         [127.6331, 225.0528, 167.0711, 332.2222]])
# xyxyn: tensor([[0.4533, 0.2213, 0.5398, 0.4429],
#         [0.2726, 0.2274, 0.3551, 0.4447],
#         [0.3616, 0.2267, 0.4487, 0.4437],
#         [0.4556, 0.4661, 0.5383, 0.6864],
# ...
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/Screenshot_20240523_100534_Pinterest_jpg.rf.adf2b6f4f6f943ebb52e3bfd31669b27.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.])
# conf: tensor([0.8882])
# data: tensor([[161.7305,  22.9651, 409.6667, 196.2987,   0.8882,   2.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([1, 6])
# xywh: tensor([[285.6986, 109.6319, 247.9361, 173.3337]])
# xywhn: tensor([[0.5952, 0.2284, 0.5165, 0.3611]])
# xyxy: tensor([[161.7305,  22.9651, 409.6667, 196.2987]])
# xyxyn: tensor([[0.3369, 0.0478, 0.8535, 0.4090]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/Poza-din-04-06-2024-de-la-10-26-2-1-_jpg.rf.8dff04a79e3fa582c3c951c727553bfe.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([ 5.,  9.,  1., 13., 17.,  9.,  1.])
# conf: tensor([0.9857, 0.8042, 0.7673, 0.5637, 0.4611, 0.4061, 0.3088])
# data: tensor([[3.5949e+02, 2.3201e+02, 4.1628e+02, 3.4332e+02, 9.8575e-01, 5.0000e+00],
#         [7.9411e+01, 2.2710e+02, 1.2061e+02, 3.3797e+02, 8.0418e-01, 9.0000e+00],
#         [1.2442e+02, 2.2316e+02, 1.6739e+02, 3.3698e+02, 7.6732e-01, 1.0000e+00],
#         [1.7260e+02, 2.2345e+02, 2.1673e+02, 3.3958e+02, 5.6369e-01, 1.3000e+01],
#         [2.2050e+02, 2.3055e+02, 2.6457e+02, 3.4077e+02, 4.6110e-01, 1.7000e+01],
#         [8.3679e+01, 1.0061e+02, 1.2483e+02, 2.1233e+02, 4.0608e-01, 9.0000e+00],
#         [1.3002e+02, 1.0172e+02, 1.7140e+02, 2.1393e+02, 3.0881e-01, 1.0000e+00]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([7, 6])
# xywh: tensor([[387.8825, 287.6637,  56.7889, 111.3121],
#         [100.0130, 282.5356,  41.2032, 110.8717],
#         [145.9062, 280.0694,  42.9645, 113.8202],
#         [194.6642, 281.5167,  44.1282, 116.1255],
#         [242.5336, 285.6611,  44.0630, 110.2144],
#         [104.2541, 156.4696,  41.1497, 111.7210],
#         [150.7116, 157.8222,  41.3764, 112.2123]])
# xywhn: tensor([[0.8081, 0.5993, 0.1183, 0.2319],
#         [0.2084, 0.5886, 0.0858, 0.2310],
#         [0.3040, 0.5835, 0.0895, 0.2371],
#         [0.4056, 0.5865, 0.0919, 0.2419],
#         [0.5053, 0.5951, 0.0918, 0.2296],
#         [0.2172, 0.3260, 0.0857, 0.2328],
#         [0.3140, 0.3288, 0.0862, 0.2338]])
# xyxy: tensor([[359.4880, 232.0077, 416.2770, 343.3198],
#         [ 79.4113, 227.0998, 120.6146, 337.9715],
#         [124.4240, 223.1593, 167.3884, 336.9795],
#         [172.6001, 223.4539, 216.7283, 339.5794],
#         [220.5022, 230.5539, 264.5651, 340.7682],
#         [ 83.6792, 100.6091, 124.8289, 212.3301],
#         [130.0234, 101.7160, 171.3998, 213.9284]])
# xyxyn: tensor([[0.7489, 0.4833, 0.8672, 0.7152],
#         [0.1654, 0.4731, 0.2513, 0.7041],
#         [0.2592, 0.4649, 0.3487, 0.7020],
#         [0.3596, 0.4655, 0.4515, 0.7075],
#         [0.4594, 0.4803, 0.5512, 0.7099],
#         [0.1743, 0.2096, 0.2601, 0.4424],
#         [0.2709, 0.2119, 0.3571, 0.4457]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/Screenshot_20240523_100750_Pinterest_jpg.rf.4cb27e5a068f39a818e36ce67cdcb15e.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2., 2.])
# conf: tensor([0.9291, 0.9210])
# data: tensor([[ 23.0376,  25.2080, 233.0164, 159.3459,   0.9291,   2.0000],
#         [231.4675,  17.6393, 444.0872, 151.8199,   0.9210,   2.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([2, 6])
# xywh: tensor([[128.0270,  92.2769, 209.9789, 134.1379],
#         [337.7773,  84.7296, 212.6197, 134.1806]])
# xywhn: tensor([[0.2667, 0.1922, 0.4375, 0.2795],
#         [0.7037, 0.1765, 0.4430, 0.2795]])
# xyxy: tensor([[ 23.0376,  25.2080, 233.0164, 159.3459],
#         [231.4675,  17.6393, 444.0872, 151.8199]])
# xyxyn: tensor([[0.0480, 0.0525, 0.4855, 0.3320],
#         [0.4822, 0.0367, 0.9252, 0.3163]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/Screenshot_20240528_151302_Pinterest_jpg.rf.4556a63d2d343c8594614cabbe2ee6c9.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2., 2., 2., 2., 2., 2., 2.])
# conf: tensor([0.9311, 0.8118, 0.7674, 0.7493, 0.6725, 0.5926, 0.5841])
# data: tensor([[ 29.2274,  50.4416, 203.0487, 116.9166,   0.9311,   2.0000],
#         [ 44.6465, 242.5840, 165.1572, 318.3028,   0.8118,   2.0000],
#         [266.0046,  96.0565, 418.0709, 178.6678,   0.7674,   2.0000],
#         [298.1136, 222.4446, 418.2587, 354.7860,   0.7493,   2.0000],
#         [ 82.1077, 134.5191, 224.3873, 196.1984,   0.6725,   2.0000],
#         [ 17.9953, 150.8033, 115.2032, 208.1624,   0.5926,   2.0000],
#         [298.6115, 391.3383, 430.5200, 428.3118,   0.5841,   2.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([7, 6])
# xywh: tensor([[116.1381,  83.6791, 173.8213,  66.4750],
#         [104.9018, 280.4434, 120.5107,  75.7188],
#         [342.0377, 137.3622, 152.0663,  82.6113],
#         [358.1861, 288.6153, 120.1451, 132.3414],
#         [153.2475, 165.3587, 142.2796,  61.6793],
#         [ 66.5993, 179.4828,  97.2079,  57.3591],
#         [364.5657, 409.8250, 131.9086,  36.9735]])
# xywhn: tensor([[0.2420, 0.1743, 0.3621, 0.1385],
#         [0.2185, 0.5843, 0.2511, 0.1577],
#         [0.7126, 0.2862, 0.3168, 0.1721],
#         [0.7462, 0.6013, 0.2503, 0.2757],
#         [0.3193, 0.3445, 0.2964, 0.1285],
#         [0.1387, 0.3739, 0.2025, 0.1195],
#         [0.7595, 0.8538, 0.2748, 0.0770]])
# xyxy: tensor([[ 29.2274,  50.4416, 203.0487, 116.9166],
#         [ 44.6465, 242.5840, 165.1572, 318.3028],
#         [266.0046,  96.0565, 418.0709, 178.6678],
#         [298.1136, 222.4446, 418.2587, 354.7860],
#         [ 82.1077, 134.5191, 224.3873, 196.1984],
#         [ 17.9953, 150.8033, 115.2032, 208.1624],
#         [298.6115, 391.3383, 430.5200, 428.3118]])
# xyxyn: tensor([[0.0609, 0.1051, 0.4230, 0.2436],
#         [0.0930, 0.5054, 0.3441, 0.6631],
#         [0.5542, 0.2001, 0.8710, 0.3722],
#         [0.6211, 0.4634, 0.8714, 0.7391],
#         [0.1711, 0.2802, 0.4675, 0.4087],
#         [0.0375, 0.3142, 0.2400, 0.4337],
#         [0.6221, 0.8153, 0.8969, 0.8923]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/Screenshot_20240528_151657_Pinterest_jpg.rf.2566b4ab8664fe4b6a5b74df2cd500dd.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([7., 7., 7., 7.])
# conf: tensor([0.9523, 0.8844, 0.8414, 0.7280])
# data: tensor([[ 10.9743, 269.1185, 236.7647, 354.0853,   0.9523,   7.0000],
#         [244.9493,  20.0849, 419.3837,  92.9621,   0.8844,   7.0000],
#         [ 24.2362, 123.8397, 228.9908, 198.4861,   0.8414,   7.0000],
#         [ 15.6109,  14.1569, 225.8762,  87.6497,   0.7280,   7.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([4, 6])
# xywh: tensor([[123.8695, 311.6019, 225.7904,  84.9668],
#         [332.1665,  56.5235, 174.4344,  72.8772],
#         [126.6135, 161.1629, 204.7546,  74.6464],
#         [120.7436,  50.9033, 210.2653,  73.4928]])
# xywhn: tensor([[0.2581, 0.6492, 0.4704, 0.1770],
#         [0.6920, 0.1178, 0.3634, 0.1518],
#         [0.2638, 0.3358, 0.4266, 0.1555],
#         [0.2515, 0.1060, 0.4381, 0.1531]])
# xyxy: tensor([[ 10.9743, 269.1185, 236.7647, 354.0853],
#         [244.9493,  20.0849, 419.3837,  92.9621],
#         [ 24.2362, 123.8397, 228.9908, 198.4861],
#         [ 15.6109,  14.1569, 225.8762,  87.6497]])
# xyxyn: tensor([[0.0229, 0.5607, 0.4933, 0.7377],
#         [0.5103, 0.0418, 0.8737, 0.1937],
#         [0.0505, 0.2580, 0.4771, 0.4135],
#         [0.0325, 0.0295, 0.4706, 0.1826]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/celecoxib-200-MG-11-Copy-Copy_jpg.rf.15a92bfbd3268f93ab421e286e008d5a.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6., 6.])
# conf: tensor([0.9715, 0.9713])
# data: tensor([[ 15.5053, 190.2364, 478.3509, 405.1336,   0.9715,   6.0000],
#         [ 15.4955,   0.0000, 478.9720, 183.8821,   0.9713,   6.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([2, 6])
# xywh: tensor([[246.9281, 297.6850, 462.8456, 214.8972],
#         [247.2338,  91.9410, 463.4765, 183.8821]])
# xywhn: tensor([[0.5144, 0.6202, 0.9643, 0.4477],
#         [0.5151, 0.1915, 0.9656, 0.3831]])
# xyxy: tensor([[ 15.5053, 190.2364, 478.3509, 405.1336],
#         [ 15.4955,   0.0000, 478.9720, 183.8821]])
# xyxyn: tensor([[0.0323, 0.3963, 0.9966, 0.8440],
#         [0.0323, 0.0000, 0.9979, 0.3831]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/
])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([18, 6])
# xywh: tensor([[223.7504, 130.6916,  42.1583, 105.0906],
#         [357.3789, 133.3880,  39.1951, 107.5119],
#         [400.8333, 135.3577,  38.2752, 112.8702],
#         [222.5114, 246.6581,  40.2715, 102.2313],
#         [268.2015, 130.7408,  39.2655, 106.7784],
#         [176.9819, 246.0221,  39.7898, 103.0543],
#         [135.7546, 131.8357,  41.1836, 107.1694],
#         [180.3036, 131.0547,  40.3425, 103.6392],
#         [268.6310, 246.6288,  40.6224, 103.3032],
#         [403.6705, 245.9749,  38.8671, 100.4342],
#         [359.9940, 247.0312,  40.4738, 102.0137],
#         [132.7512, 247.9700,  38.4220,  97.0612],
#         [313.9663, 247.3014,  42.2887, 102.4323],
#         [312.6816, 131.6847,  41.0330, 107.1099],
#         [403.7973, 247.0717,  37.9572,  99.2107],
#         [313.0924, 131.1541,  42.1472, 106.6599],
#         [224.8527, 132.1790,  41.6325, 107.0609],
#         [132.3705, 247.7487,  38.1252,  99.7347]])
# xywhn: tensor([[0.4661, 0.2723, 0.0878, 0.2189],
#         [0.7445, 0.2779, 0.0817, 0.2240],
#         [0.8351, 0.2820, 0.0797, 0.2351],
#         [0.4636, 0.5139, 0.0839, 0.2130],
#         [0.5588, 0.2724, 0.0818, 0.2225],
#         [0.3687, 0.5125, 0.0829, 0.2147],
#         [0.2828, 0.2747, 0.0858, 0.2233],
#         [0.3756, 0.2730, 0.0840, 0.2159],
#         [0.5596, 0.5138, 0.0846, 0.2152],
#         [0.8410, 0.5124, 0.0810, 0.2092],
#         [0.7500, 0.5146, 0.0843, 0.2125],
#         [0.2766, 0.5166, 0.0800, 0.2022],
#         [0.6541, 0.5152, 0.0881, 0.2134],
#         [0.6514, 0.2743, 0.0855, 0.2231],
#         [0.8412, 0.5147, 0.0791, 0.2067],
#         [0.6523, 0.2732, 0.0878, 0.2222],
#         [0.4684, 0.2754, 0.0867, 0.2230],
#         [0.2758, 0.5161, 0.0794, 0.2078]])
# xyxy: tensor([[202.6712,  78.1463, 244.8295, 183.2368],
#         [337.7814,  79.6321, 376.9764, 187.1440],
#         [381.6957,  78.9226, 419.9709, 191.7928],
#         [202.3756, 195.5424, 242.6471, 297.7737],
#         [248.5688,  77.3516, 287.8343, 184.1300],
#         [157.0870, 194.4949, 196.8768, 297.5493],
#         [115.1628,  78.2510, 156.3464, 185.4204],
#         [160.1323,  79.2352, 200.4748, 182.8743],
#         [248.3198, 194.9772, 288.9423, 298.2804],
#         [384.2369, 195.7578, 423.1041, 296.1920],
#         [339.7571, 196.0244, 380.2308, 298.0381],
#         [113.5402, 199.4395, 151.9622, 296.5006],
#         [292.8220, 196.0853, 335.1107, 298.5175],
#         [292.1651,  78.1298, 333.1981, 185.2397],
#         [384.8187, 197.4664, 422.7759, 296.6771],
#         [292.0188,  77.8242, 334.1660, 184.4841],
#         [204.0364,  78.6485, 245.6689, 185.7094],
#         [113.3079, 197.8813, 151.4331, 297.6161]])
# xyxyn: tensor([[0.4222, 0.1628, 0.5101, 0.3817],
#         [0.7037, 0.1659, 0.7854, 0.3899],
#         [0.7952, 0.1644, 0.8749, 0.3996],
#         [0.4216, 0.4074, 0.5055, 0.6204],
#         [0.5179, 0.1611, 0.5997, 0.3836],
#         [0.3273, 0.4052, 0.4102, 0.6199],
#         [0.2399, 0.1630, 0.3257, 0.3863],
#         [0.3336, 0.1651, 0.4177, 0.3810],
#         [0.5173, 0.4062, 0.6020, 0.6214],
#         [0.8005, 0.4078, 0.8815, 0.6171],
#         [0.7078, 0.4084, 0.7921, 0.6209],
#         [0.2365, 0.4155, 0.3166, 0.6177],
#         [0.6100, 0.4085, 0.6981, 0.6219],
#         [0.6087, 0.1628, 0.6942, 0.3859],
#         [0.8017, 0.4114, 0.8808, 0.6181],
#         [0.6084, 0.1621, 0.6962, 0.3843],
#         [0.4251, 0.1639, 0.5118, 0.3869],
#         [0.2361, 0.4123, 0.3155, 0.6200]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/Screenshot_20240522_210046_SHEIN_jpg.rf.f75e6fd9c68f57eedb85d63572d32117.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([7.])
# conf: tensor([0.6927])
# data: tensor([[ 56.8727,  90.3275, 435.2517, 385.1099,   0.6927,   7.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([1, 6])
# xywh: tensor([[246.0622, 237.7187, 378.3789, 294.7824]])
# xywhn: tensor([[0.5126, 0.4952, 0.7883, 0.6141]])
# xyxy: tensor([[ 56.8727,  90.3275, 435.2517, 385.1099]])
# xyxyn: tensor([[0.1185, 0.1882, 0.9068, 0.8023]])
# Image: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v4i.yolov8/test/images/medicine-4-_jpg.rf.20b9cb609c87be6f6dff2e78af16926d.jpg
# Predictions: ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([6., 6., 6.])
# conf: tensor([0.8389, 0.8388, 0.7385])
# data: tensor([[192.5998, 219.7785, 282.3332, 316.2546,   0.8389,   6.0000],
#         [217.8750,  96.3409, 323.5763, 198.2290,   0.8388,   6.0000],
#         [118.4574, 247.1859, 211.7527, 345.2634,   0.7385,   6.0000]])
# id: None
# is_track: False
# orig_shape: (480, 480)
# shape: torch.Size([3, 6])
# xywh: tensor([[237.4665, 268.0166,  89.7334,  96.4761],
#         [270.7257, 147.2849, 105.7013, 101.8881],
#         [165.1051, 296.2246,  93.2953,  98.0775]])
# xywhn: tensor([[0.4947, 0.5584, 0.1869, 0.2010],
#         [0.5640, 0.3068, 0.2202, 0.2123],
#         [0.3440, 0.6171, 0.1944, 0.2043]])
# xyxy: tensor([[192.5998, 219.7785, 282.3332, 316.2546],
#         [217.8750,  96.3409, 323.5763, 198.2290],
#         [118.4574, 247.1859, 211.7527, 345.2634]])
# xyxyn: tensor([[0.4012, 0.4579, 0.5882, 0.6589],
#         [0.4539, 0.2007, 0.6741, 0.4130],
#         [0.2468, 0.5150, 0.4412, 0.7193]])

# %%
import cv2
from ultralytics import YOLO
from PIL import Image, ImageTk
import tkinter as tk
import socket
import threading
import time


# Load the trained YOLOv8 model
try:
    model = YOLO('runs/detect/train2/weights/best.pt')
except Exception as e:
    print(f"Error loading model: {e}")
    exit()

# Define the class names
class_names = ['Hands', 'Open', 'Pill', 'PillBox']

# Server address and port for Raspberry Pi
server_address = ('192.168.168.167', 1442)  # Change this to your Raspberry Pi IP and port

# Global vars for use in methods/threads
client_socket = None
receive_thread = None
shutdown_flag = threading.Event()
last_notification_time = 0
notification_interval = 1

def setup_socket_client():
    global client_socket, receive_thread
    client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)  # Create a socket instance
    client_socket.connect(server_address)  # Connect to specified server
    print("Connected to server")

    receive_thread = threading.Thread(target=receive_messages, args=(client_socket, shutdown_flag))
    receive_thread.start()

def receive_messages(sock, shutdown_flag):
    sock.settimeout(1)  # Set a timeout on the socket so we can check shutdown_flag.is_set in the loop, instead of blocking
    try:
        while not shutdown_flag.is_set():  # As long as ctrl+c is not pressed
            try:
                data = sock.recv(1024)  # Try to receive 1024 bytes of data (maximum amount; can be less)
                if not data:  # When no data is received, try again (and shutdown flag is checked again)
                    break
                print("Received from server:", data.decode())  # Print the received data, or do something with it
            except socket.timeout:  # When no data comes within timeout, try again
                continue
    except Exception as e:
        if not shutdown_flag.is_set():
            print(f"Connection error: {e}")
    finally:
        sock.close()

# Function to draw bounding boxes with different colors
def draw_bounding_boxes(image, results):
    global last_notification_time
    boxes = results[0].boxes.xyxy.cpu().numpy()
    confs = results[0].boxes.conf.cpu().numpy()
    classes = results[0].boxes.cls.cpu().numpy()
    for i, box in enumerate(boxes):
        x1, y1, x2, y2 = map(int, box)
        conf = confs[i]
        cls = int(classes[i])
        label = class_names[cls]
        if label == 'Hands':
            color = (0, 255, 0)  # Green
        elif label == 'Pill':
            color = (255, 0, 0)  # Red
            # Send notification to Raspberry Pi when wrong pill is detected
            current_time = time.time()
            if current_time - last_notification_time >= notification_interval:
                notify_raspberry_pi("Wrong pill detected")
                last_notification_time = current_time
            print('-------- Pill Detected ---------')
        elif label == 'Open':
            color = (255,255,0)
        else:
            color = (0, 0, 255)  # Blue
            # Draw a horizontal line in the middle of the bounding box
            cv2.line(image, (x1, (y1+y2)//2), (x2, (y1+y2)//2), (255, 255, 255), 2)
            # Draw 6 lines vertically
            for i in range (1,7):
                cv2.line(image, (x1 + i*(x2-x1)//7, y1), (x1 + i*(x2-x1)//7, y2), (255, 255, 255), 2)
        cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)
        cv2.putText(image, f'{label} {conf:.2f}', (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)
    return image

# Function to notify Raspberry Pi
def notify_raspberry_pi(message):
    try:
        client_socket.sendall(message.encode())
        print(f"Sent to Raspberry Pi: {message}")
    except Exception as e:
        print(f"Error sending message to Raspberry Pi: {e}")

# Initialize the webcam
cap = cv2.VideoCapture(0)  # Use 0 for the default webcam, or specify the webcam index

def update_frame():
    ret, frame = cap.read()
    if not ret:
        print("Error reading frame from webcam")
        return

    # Perform inference with adjusted NMS settings
    try:
        results = model(frame)
    except Exception as e:
        print(f"Error performing inference: {e}")
        return

    # Annotate the frame with detection results
    frame = draw_bounding_boxes(frame, results)

    # Convert the frame to an ImageTk object
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    img = Image.fromarray(frame_rgb)
    imgtk = ImageTk.PhotoImage(image=img)

    # Update the label with the new image
    lbl.imgtk = imgtk  # Keep a reference to the image to prevent garbage collection
    lbl.configure(image=imgtk)

    # Schedule the next update
    lbl.after(10, update_frame)
# Create the main window
root = tk.Tk()
root.title("Webcam Detection")

# Create a label to display the video feed
lbl = tk.Label(root)
lbl.pack()

# Setup the socket client and start the update loop
setup_socket_client()
root.after(0, update_frame)
root.mainloop()

# Cleanup
cap.release()
shutdown_flag.set()
if client_socket:
    client_socket.close()
if receive_thread:
    receive_thread.join()
