# %%
import yaml
import os

with open('data.yaml', 'r') as file:
    data = yaml.safe_load(file)

print("Train path:", os.path.exists(data['train']))
print("Validation path:", os.path.exists(data['val']))
print("Test path:", os.path.exists(data['test']))

def count_images(directory):
    supported_formats = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.tif')
    return len([name for name in os.listdir(directory) if name.lower().endswith(supported_formats)])

print(f" The number of images in training set: {count_images(data['train'])}")
print(f" The number of images in validation set: {count_images(data['val'])}")
print(f" The number of images in test set: {count_images(data['test'])}")
# Out:
# Train path: True
# Validation path: True
# Test path: True
#  The number of images in training set: 3093
#  The number of images in validation set: 254
#  The number of images in test set: 117

# %%
from ultralytics import YOLO
from pathlib import Path

absolute_from_relative_path = Path('data.yaml').resolve()

model = YOLO('yolov8n.pt')  # Load a pretrained model (recommended for training)
results = model.train(data=absolute_from_relative_path, epochs=20, imgsz=480)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
#   0%|          | 0.00/6.23M [00:00<?, ?B/s]
# New https://pypi.org/project/ultralytics/8.2.31 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.227 🚀 Python-3.9.18 torch-1.13.1 CPU (Apple M1)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v7i.yolov8/data.yaml, epochs=20, patience=50, batch=16, imgsz=480, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Overriding model.yaml nc=80 with nc=18
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    754822  ultralytics.nn.modules.head.Detect           [18, [64, 128, 256]]
# Fontconfig warning: ignoring UTF-8: not a valid region tag
# [W NNPACK.cpp:53] Could not initialize NNPACK! Reason: Unsupported hardware.
# Model summary: 225 layers, 3014358 parameters, 3014342 gradients
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v7i.yolov8/train/labels... 3093 images, 0 backgrounds, 0 corrupt: 100%|██████████| 3093/3093 [00:01<00:00, 2339.67it/s]
# train: New cache created: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v7i.yolov8/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 3633, len(boxes) = 20391. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Scanning /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v7i.yolov8/valid/labels... 254 images, 0 backgrounds, 0 corrupt: 100%|██████████| 254/254 [00:00<00:00, 2522.10it/s]
# val: New cache created: /Users/alessiacolumban/Desktop/2023-2024-projectone-ctai-AlessCol7/PillPoint/AI/PillPoint.v7i.yolov8/valid/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 177, len(boxes) = 1403. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000455, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 480 train, 480 val
# Using 0 dataloader workers
# Logging results to runs/detect/train
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20         0G      1.594      3.326      1.422         14        480: 100%|██████████| 194/194 [14:46<00:00,  4.57s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:23<00:00,  2.93s/it]
#                    all        254       1403      0.199      0.566      0.241      0.147
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20         0G      1.405      2.095      1.296         24        480: 100%|██████████| 194/194 [11:43<00:00,  3.63s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:23<00:00,  2.89s/it]
#                    all        254       1403      0.245      0.499      0.319      0.194
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20         0G      1.345      1.861      1.258         28        480: 100%|██████████| 194/194 [11:30<00:00,  3.56s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:23<00:00,  2.93s/it]
#                    all        254       1403      0.361      0.638      0.467      0.284
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20         0G      1.323      1.635      1.257         29        480: 100%|██████████| 194/194 [11:26<00:00,  3.54s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:23<00:00,  2.98s/it]
#                    all        254       1403      0.613      0.573      0.624      0.383
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20         0G      1.296      1.439      1.241         79        480: 100%|██████████| 194/194 [12:08<00:00,  3.76s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:23<00:00,  2.93s/it]
#                    all        254       1403      0.811      0.713      0.803      0.511
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20         0G      1.272      1.356      1.226         37        480: 100%|██████████| 194/194 [11:14<00:00,  3.48s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:23<00:00,  2.89s/it]
#                    all        254       1403      0.824      0.752      0.834       0.53
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20         0G      1.265      1.249      1.222         65        480: 100%|██████████| 194/194 [11:18<00:00,  3.50s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:23<00:00,  2.95s/it]
#                    all        254       1403      0.892      0.776       0.87      0.572
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20         0G      1.238      1.175      1.204         31        480: 100%|██████████| 194/194 [11:03<00:00,  3.42s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:23<00:00,  2.92s/it]
#                    all        254       1403      0.871        0.8      0.874      0.571
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20         0G      1.212      1.126      1.177         23        480: 100%|██████████| 194/194 [11:28<00:00,  3.55s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:22<00:00,  2.87s/it]
#                    all        254       1403      0.905      0.802      0.884      0.584
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20         0G      1.209      1.097      1.181         36        480: 100%|██████████| 194/194 [29:55<00:00,  9.25s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:23<00:00,  2.88s/it]
#                    all        254       1403      0.898      0.826      0.894      0.586
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20         0G      1.177     0.9629      1.194         53        480: 100%|██████████| 194/194 [11:37<00:00,  3.60s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:23<00:00,  2.90s/it]
#                    all        254       1403      0.901      0.838      0.909      0.595
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20         0G      1.149     0.9121      1.179         74        480: 100%|██████████| 194/194 [11:56<00:00,  3.69s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:23<00:00,  2.88s/it]
#                    all        254       1403      0.909      0.839      0.907      0.609
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20         0G      1.136     0.8603      1.172         18        480: 100%|██████████| 194/194 [11:54<00:00,  3.68s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:24<00:00,  3.12s/it]
#                    all        254       1403       0.91      0.863      0.922      0.619
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20         0G       1.11     0.8285      1.151         38        480: 100%|██████████| 194/194 [11:35<00:00,  3.58s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:23<00:00,  2.91s/it]
#                    all        254       1403      0.915      0.861      0.924      0.617
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20         0G      1.085     0.7965      1.143         37        480: 100%|██████████| 194/194 [11:53<00:00,  3.68s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:23<00:00,  2.90s/it]
#                    all        254       1403      0.902      0.895      0.933      0.623
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20         0G      1.074     0.7796      1.133         24        480: 100%|██████████| 194/194 [11:31<00:00,  3.57s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:23<00:00,  2.99s/it]
#                    all        254       1403      0.913      0.873      0.926      0.626
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20         0G      1.054     0.7539       1.12         22        480: 100%|██████████| 194/194 [11:20<00:00,  3.51s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:23<00:00,  2.88s/it]
#                    all        254       1403      0.931      0.871      0.933      0.636
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20         0G      1.035     0.7311       1.11         38        480: 100%|██████████| 194/194 [12:00<00:00,  3.71s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:24<00:00,  3.10s/it]
#                    all        254       1403      0.925       0.87      0.937      0.636
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20         0G       1.02     0.7169      1.104         20        480: 100%|██████████| 194/194 [11:44<00:00,  3.63s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:23<00:00,  2.93s/it]
#                    all        254       1403      0.919      0.873      0.931      0.637
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20         0G      1.005     0.7011      1.098         33        480: 100%|██████████| 194/194 [12:09<00:00,  3.76s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:24<00:00,  3.01s/it]
#                    all        254       1403      0.931      0.892      0.939      0.648
# 20 epochs completed in 4.371 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.227 🚀 Python-3.9.18 torch-1.13.1 CPU (Apple M1)
# Model summary (fused): 168 layers, 3009158 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:28<00:00,  3.54s/it]
#                    all        254       1403      0.936      0.889      0.939      0.648
#                 FRI-am        254         57      0.954      0.947      0.976      0.686
#                 FRI-pm        254         57          1      0.894      0.973      0.687
#                  Hands        254        263      0.896      0.856      0.942      0.545
#                 MON-am        254         55      0.954      0.945      0.974      0.678
#                 MON-pm        254         56      0.961      0.982       0.99      0.689
#                   Open        254         89      0.754      0.585      0.697       0.39
#                   Pill        254        164      0.838      0.818      0.905      0.624
#                PillBox        254         98      0.955      0.863      0.921      0.635
#                 SAT-am        254         57      0.947      0.937      0.941      0.704
#                 SAT-pm        254         57      0.928      0.907      0.928      0.687
#                 SUN-am        254         54      0.918      0.832      0.921      0.611
#                 SUN-pm        254         57      0.921      0.912      0.944      0.672
#                 THU-am        254         61          1      0.902      0.979      0.659
#                 THU-pm        254         57      0.996       0.93       0.96      0.663
#                 TUE-am        254         52      0.908      0.923       0.95      0.707
#                 TUE-pm        254         54      0.981      0.941      0.981      0.693
#                 WED-am        254         60      0.982      0.911      0.963      0.683
#                 WED-pm        254         55      0.958      0.909      0.966      0.657
# Speed: 1.3ms preprocess, 104.9ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs/detect/train

# %%
import cv2  # OpenCV library for computer vision tasks
from ultralytics import YOLO  # YOLO model for object detection
from PIL import Image, ImageTk  # PIL for image processing and integration with Tkinter
import tkinter as tk  # Tkinter for GUI
import socket  # Socket for network communication
import threading  # Threading for concurrent operations
import time  # Time for handling time-related operations

# Load the trained YOLOv8 model
try:
    model = YOLO('runs/detect/train/weights/best.pt')
except Exception as e:
    print(f"Error loading model: {e}")
    exit()

# Define the class names
class_names = ['FRI-am', 'FRI-pm', 'Hands', 'MON-am', 'MON-pm', 'Open', 'Pill', 'PillBox', 'SAT-am', 'SAT-pm', 'SUN-am', 'SUN-pm', 'THU-am', 'THU-pm', 'TUE-am', 'TUE-pm', 'WED-am', 'WED-pm']

# Define colors for each class visualization
class_colors = {
    'FRI-am': (0, 255, 255),
    'FRI-pm': (255, 255, 0),
    'Hands': (0, 255, 0),
    'MON-am': (255, 0, 255),
    'MON-pm': (0, 255, 255),
    'Open': (255, 255, 0),
    'Pill': (255, 0, 0),
    'PillBox': (0, 255, 255),
    'SAT-am': (255, 165, 0),
    'SAT-pm': (255, 69, 0),
    'SUN-am': (128, 0, 128),
    'SUN-pm': (75, 0, 130),
    'THU-am': (0, 255, 255),
    'THU-pm': (0, 128, 128),
    'TUE-am': (255, 0, 255),
    'TUE-pm': (128, 0, 0),
    'WED-am': (0, 0, 255),
    'WED-pm': (0, 128, 0)
}

# Server address and port for Raspberry Pi
server_address = ('192.168.168.167', 1443)  # Change this to your Raspberry Pi IP and port

# Global vars for use in methods/threads
client_socket = None
receive_thread = None
shutdown_flag = threading.Event()
last_debug_time = time.time()
debug_interval = 2
current_day_time = None

def setup_socket_client():
    global client_socket, receive_thread
    client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)  # Create a socket instance
    client_socket.connect(server_address)  # Connect to specified server
    print("Connected to server")

    # Start a thread to handle incoming messages
    receive_thread = threading.Thread(target=receive_messages, args=(client_socket, shutdown_flag))
    receive_thread.start()

def receive_messages(sock, shutdown_flag):
    global current_day_time
    sock.settimeout(1)  # Set a timeout on the socket so we can check shutdown_flag.is_set in the loop, instead of blocking
    try:
        while not shutdown_flag.is_set():  # As long as ctrl+c is not pressed
            try:
                data = sock.recv(1024)  # Try to receive 1024 bytes of data (maximum amount; can be less)
                if not data:  # When no data is received, try again (and shutdown flag is checked again)
                    break
                current_day_time = data.decode()
                print("Received from server:", current_day_time)  # Print the received data, or do something with it
            except socket.timeout:  # When no data comes within timeout, try again
                continue
    except Exception as e:
        if not shutdown_flag.is_set():
            print(f"Connection error: {e}")
    finally:
        sock.close()

def request_date_time():
    global client_socket
    try:
        client_socket.sendall("Request date and time".encode())
    except Exception as e:
        print(f"Failed to request date and time: {e}")

# Function to draw bounding boxes with different colors
def draw_bounding_boxes(image, results):
    global last_debug_time, current_day_time
    boxes = results[0].boxes.xyxy.cpu().numpy()
    confs = results[0].boxes.conf.cpu().numpy()
    classes = results[0].boxes.cls.cpu().numpy()
    
    pillbox_detected = False
    compartment_open_detected = False
    wrong_compartment_opened = False

    for i, box in enumerate(boxes):
        x1, y1, x2, y2 = map(int, box)
        conf = confs[i]
        cls = int(classes[i])
        label = class_names[cls]
        
        color = class_colors.get(label, (0, 0, 255))  # Default to blue if not found
        
        cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)
        cv2.putText(image, f'{label} {confs[i]:.2f}', (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)
        
        if label == 'PillBox':
            pillbox_detected = True

        if label == 'Open':
            compartment_open_detected = True
            
        # Check if the open compartment matches the expected compartment
        if current_day_time and label not in current_day_time:
            wrong_compartment_opened = True

        # Check if it's time to print debug statements
        if last_debug_time + debug_interval < time.time():
            # Debug statements to verify logic
            print(f"Label: {label}")
            print(f"Current Day and Time: {current_day_time}")
            print(f"Pillbox Detected: {pillbox_detected}")
            print(f"Compartment Open Detected: {compartment_open_detected}")
            print(f"Wrong Compartment Opened: {wrong_compartment_opened}")
            # Update the last debug time
            last_debug_time = time.time()
        

    if pillbox_detected and compartment_open_detected and wrong_compartment_opened:
        send_buzzer_notification()

def send_buzzer_notification():
    global client_socket
    try:
        client_socket.sendall("Wrong pill detected".encode())
    except Exception as e:
        print(f"Failed to send buzzer notification: {e}")

# AI part
def process_frame(frame):
    # Perform inference with the YOLOv8 model
    try:
        results = model(frame)
    except Exception as e:
        print(f"Error performing inference: {e}")
        return frame

    # Annotate the frame with detection results
    draw_bounding_boxes(frame, results)

    return frame

# Tkinter GUI part
def update_frame():
    ret, frame = cap.read()
    if ret:
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Convert colorspace from BGR to RGB
        frame = process_frame(frame) #Calls process_frame(frame) to perform object detection and annotation on the frame.
        img = Image.fromarray(frame)  #Converts the processed frame (which is a numpy array) to a PIL Image object using Image.fromarray.
        imgtk = ImageTk.PhotoImage(image=img) #Converts the PIL Image to a format suitable for displaying in a Tkinter GUI using ImageTk.PhotoImage.
        label_img.imgtk = imgtk #Updates the image displayed in the Tkinter Label widget (label_img) with the new frame by setting its image attribute to imgtk.
        label_img.configure(image=imgtk)
    else:
        print("Error reading frame from webcam")
    label_img.after(10, update_frame)  # Schedule the update after 10 milliseconds

# Initialize the webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Setup Tkinter window
window = tk.Tk()
window.title("Pill Detection")
window.geometry("800x600")

# Create a label to display the webcam feed
label_img = tk.Label(window)
label_img.pack()

# Start the socket client
setup_socket_client()

# Request the initial date and time
request_date_time()

# Start the webcam feed update
update_frame()

# Start the Tkinter event loop
window.mainloop()

# Release the webcam
cap.release()
# Out:
# [ WARN:0@100.518] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_f6tvh9615u/croot/opencv-suite_1691620375715/work/modules/videoio/src/cap_gstreamer.cpp (862) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# Connected to server
# Received from server: Wed-PM
# Received from server: Wed-PM
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 2 WED-pms, 60.8ms
# Speed: 1.6ms preprocess, 60.8ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 50.4ms
# Speed: 1.5ms preprocess, 50.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: WED-pm
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: True
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 2 WED-pms, 55.0ms
# Speed: 1.2ms preprocess, 55.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 49.5ms
# Speed: 1.1ms preprocess, 49.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 42.4ms
# Speed: 1.4ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 41.5ms
# Speed: 2.5ms preprocess, 41.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 2 WED-pms, 40.8ms
# Speed: 1.2ms preprocess, 40.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 43.0ms
# Speed: 1.3ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 2 WED-pms, 42.7ms
# Speed: 1.2ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 41.4ms
# Speed: 1.8ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 43.9ms
# Speed: 1.2ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 41.0ms
# Speed: 1.1ms preprocess, 41.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 2 WED-pms, 47.3ms
# Speed: 1.8ms preprocess, 47.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 44.5ms
# Speed: 1.0ms preprocess, 44.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 2 WED-pms, 42.0ms
# Speed: 1.3ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 2 WED-pms, 45.8ms
# Speed: 1.0ms preprocess, 45.8ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 40.5ms
# Speed: 1.2ms preprocess, 40.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: WED-pm
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: True
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 2 WED-pms, 43.6ms
# Speed: 1.1ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 2 WED-pms, 44.0ms
# Speed: 1.1ms preprocess, 44.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 2 WED-pms, 42.8ms
# Speed: 1.0ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 40.5ms
# Speed: 1.0ms preprocess, 40.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 43.5ms
# Speed: 1.2ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 41.2ms
# Speed: 1.0ms preprocess, 41.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 68.6ms
# Speed: 1.2ms preprocess, 68.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 2 WED-pms, 43.3ms
# Speed: 1.1ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 69.8ms
# Speed: 2.0ms preprocess, 69.8ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 69.1ms
# Speed: 1.2ms preprocess, 69.1ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 89.3ms
# Speed: 1.5ms preprocess, 89.3ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 95.6ms
# Speed: 1.2ms preprocess, 95.6ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 97.7ms
# Speed: 1.3ms preprocess, 97.7ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 127.8ms
# Speed: 1.6ms preprocess, 127.8ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
# Label: WED-pm
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: True
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 95.2ms
# Speed: 1.8ms preprocess, 95.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 40.0ms
# Speed: 1.4ms preprocess, 40.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 42.8ms
# Speed: 1.5ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 41.4ms
# Speed: 1.2ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 43.6ms
# Speed: 1.2ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 44.4ms
# Speed: 1.3ms preprocess, 44.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 42.5ms
# Speed: 1.2ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 41.2ms
# Speed: 1.1ms preprocess, 41.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 2 WED-pms, 41.3ms
# Speed: 1.1ms preprocess, 41.3ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 45.6ms
# Speed: 1.0ms preprocess, 45.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 43.6ms
# Speed: 1.1ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 2 WED-pms, 42.1ms
# Speed: 1.3ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 43.4ms
# Speed: 1.1ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 41.8ms
# Speed: 1.5ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 2 WED-pms, 41.4ms
# Speed: 1.5ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: WED-pm
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: True
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 46.2ms
# Speed: 1.4ms preprocess, 46.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 42.1ms
# Speed: 1.2ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 45.9ms
# Speed: 1.2ms preprocess, 45.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 2 WED-pms, 41.5ms
# Speed: 1.1ms preprocess, 41.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 40.2ms
# Speed: 1.4ms preprocess, 40.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 2 WED-pms, 43.6ms
# Speed: 1.1ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 40.7ms
# Speed: 1.2ms preprocess, 40.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 41.2ms
# Speed: 1.1ms preprocess, 41.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 44.3ms
# Speed: 1.3ms preprocess, 44.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: WED-pm
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: True
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 42.4ms
# Speed: 1.2ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 43.4ms
# Speed: 1.1ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 48.2ms
# Speed: 1.5ms preprocess, 48.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 Hands, 1 MON-am, 1 MON-pm, 1 PillBox, 1 SAT-am, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-am, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 1 WED-am, 1 WED-pm, 43.0ms
# Speed: 1.1ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-pm, 1 MON-am, 1 MON-pm, 1 PillBox, 2 SAT-pms, 1 SUN-am, 1 SUN-pm, 1 THU-pm, 1 TUE-am, 1 TUE-pm, 2 WED-pms, 42.7ms
# Speed: 1.1ms preprocess, 42.7ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-pm, 1 MON-am, 1 SAT-am, 1 SAT-pm, 1 SUN-pm, 2 WED-pms, 45.9ms
# Speed: 1.4ms preprocess, 45.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 Hands, 1 SAT-am, 1 SAT-pm, 2 WED-pms, 44.2ms
# Speed: 1.0ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 Hands, 1 SAT-am, 1 SAT-pm, 1 THU-pm, 1 WED-pm, 65.8ms
# Speed: 1.2ms preprocess, 65.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 SAT-am, 1 SAT-pm, 1 THU-pm, 1 WED-pm, 42.0ms
# Speed: 1.2ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 SAT-am, 1 SAT-pm, 1 THU-pm, 2 WED-pms, 44.2ms
# Speed: 1.4ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 SAT-am, 1 SAT-pm, 1 THU-am, 2 WED-pms, 40.2ms
# Speed: 1.2ms preprocess, 40.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 SAT-am, 1 SAT-pm, 2 THU-ams, 1 THU-pm, 2 WED-pms, 52.5ms
# Speed: 1.2ms preprocess, 52.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 SAT-am, 1 THU-am, 1 THU-pm, 2 WED-pms, 43.7ms
# Speed: 1.2ms preprocess, 43.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: WED-pm
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: True
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 SAT-am, 1 SAT-pm, 1 THU-am, 1 THU-pm, 1 TUE-pm, 3 WED-pms, 41.9ms
# Speed: 1.1ms preprocess, 41.9ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 SAT-am, 1 SAT-pm, 1 THU-am, 1 THU-pm, 2 WED-pms, 43.0ms
# Speed: 1.3ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 SAT-am, 1 SAT-pm, 1 THU-am, 1 THU-pm, 2 WED-pms, 45.1ms
# Speed: 1.9ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 SAT-am, 1 SAT-pm, 1 THU-am, 1 THU-pm, 2 WED-pms, 45.3ms
# Speed: 1.2ms preprocess, 45.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 1 SAT-am, 1 SAT-pm, 39.9ms
# Speed: 1.1ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 43.9ms
# Speed: 1.2ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 1 SAT-pm, 47.2ms
# Speed: 1.2ms preprocess, 47.2ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 (no detections), 40.7ms
# Speed: 1.1ms preprocess, 40.7ms inference, 0.3ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Handss, 1 SAT-am, 1 SAT-pm, 43.3ms
# Speed: 1.1ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 2 Handss, 1 SAT-am, 1 SAT-pm, 48.0ms
# Speed: 1.3ms preprocess, 48.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 1 SAT-am, 1 SAT-pm, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 1 SAT-am, 1 SAT-pm, 43.8ms
# Speed: 1.3ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: Hands
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: True
#
# 0: 288x480 1 Hands, 1 SAT-am, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 40.4ms
# Speed: 1.2ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 41.9ms
# Speed: 1.1ms preprocess, 41.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 45.1ms
# Speed: 1.4ms preprocess, 45.1ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 40.5ms
# Speed: 1.3ms preprocess, 40.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 40.7ms
# Speed: 1.1ms preprocess, 40.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 45.4ms
# Speed: 1.3ms preprocess, 45.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 43.5ms
# Speed: 1.1ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 (no detections), 40.3ms
# Speed: 1.1ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 44.6ms
# Speed: 1.3ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 47.6ms
# Speed: 1.2ms preprocess, 47.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 1 PillBox, 40.4ms
# Speed: 1.1ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 41.5ms
# Speed: 1.1ms preprocess, 41.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: PillBox
# Current Day and Time: Wed-PM
# Pillbox Detected: True
# Compartment Open Detected: False
# Wrong Compartment Opened: True
#
# 0: 288x480 1 PillBox, 46.6ms
# Speed: 1.2ms preprocess, 46.6ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 39.7ms
# Speed: 1.6ms preprocess, 39.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 1 PillBox, 41.1ms
# Speed: 1.1ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 1 PillBox, 44.1ms
# Speed: 1.4ms preprocess, 44.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 41.2ms
# Speed: 1.2ms preprocess, 41.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 40.5ms
# Speed: 1.4ms preprocess, 40.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 44.7ms
# Speed: 1.2ms preprocess, 44.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 PillBox, 40.3ms
# Speed: 1.2ms preprocess, 40.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 1 PillBox, 48.2ms
# Speed: 1.1ms preprocess, 48.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 1 PillBox, 47.0ms
# Speed: 1.2ms preprocess, 47.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 1 Open, 42.8ms
# Speed: 1.2ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 40.5ms
# Speed: 1.1ms preprocess, 40.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: Open
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 1 Open, 43.2ms
# Speed: 1.2ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 42.6ms
# Speed: 1.0ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 41.5ms
# Speed: 1.2ms preprocess, 41.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 41.4ms
# Speed: 1.5ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 45.1ms
# Speed: 1.3ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 41.4ms
# Speed: 1.1ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 44.6ms
# Speed: 1.1ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 42.6ms
# Speed: 1.3ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 43.0ms
# Speed: 1.2ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 41.1ms
# Speed: 1.0ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 41.1ms
# Speed: 1.7ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 43.8ms
# Speed: 1.1ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 41.0ms
# Speed: 1.0ms preprocess, 41.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: Open
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 1 Open, 41.6ms
# Speed: 1.1ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 43.0ms
# Speed: 1.2ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 43.2ms
# Speed: 1.2ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 42.2ms
# Speed: 1.2ms preprocess, 42.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 44.0ms
# Speed: 1.3ms preprocess, 44.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 45.6ms
# Speed: 1.2ms preprocess, 45.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 41.4ms
# Speed: 1.2ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 41.5ms
# Speed: 1.3ms preprocess, 41.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 45.8ms
# Speed: 1.1ms preprocess, 45.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.1ms
# Speed: 1.1ms preprocess, 42.1ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 39.3ms
# Speed: 1.1ms preprocess, 39.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# Received from server: Wed-PM
# 0: 288x480 2 Opens, 50.3ms
# Speed: 1.3ms preprocess, 50.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 41.1ms
# Speed: 1.1ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: Open
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 2 Opens, 40.6ms
# Speed: 1.1ms preprocess, 40.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 48.4ms
# Speed: 1.2ms preprocess, 48.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.1ms
# Speed: 1.1ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 41.1ms
# Speed: 1.2ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 43.4ms
# Speed: 1.1ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 40.8ms
# Speed: 1.2ms preprocess, 40.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 41.7ms
# Speed: 1.1ms preprocess, 41.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 46.0ms
# Speed: 1.2ms preprocess, 46.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 41.4ms
# Speed: 1.1ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.5ms
# Speed: 1.0ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 41.2ms
# Speed: 1.3ms preprocess, 41.2ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 43.6ms
# Speed: 1.5ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: Open
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 1 Open, 42.9ms
# Speed: 1.1ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 40.9ms
# Speed: 1.4ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 43.5ms
# Speed: 1.1ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 42.1ms
# Speed: 1.2ms preprocess, 42.1ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 40.3ms
# Speed: 1.2ms preprocess, 40.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 42.8ms
# Speed: 1.2ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 47.6ms
# Speed: 1.2ms preprocess, 47.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 44.7ms
# Speed: 1.1ms preprocess, 44.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 40.8ms
# Speed: 1.5ms preprocess, 40.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 43.6ms
# Speed: 1.3ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 43.7ms
# Speed: 1.1ms preprocess, 43.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 41.0ms
# Speed: 1.4ms preprocess, 41.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 44.6ms
# Speed: 1.3ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: Open
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 1 Open, 41.7ms
# Speed: 1.0ms preprocess, 41.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 42.5ms
# Speed: 1.2ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 43.4ms
# Speed: 1.2ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 39.4ms
# Speed: 1.2ms preprocess, 39.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 SAT-am, 1 SAT-pm, 2 THU-pms, 1 TUE-pm, 1 WED-pm, 41.2ms
# Speed: 1.1ms preprocess, 41.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 SAT-am, 1 SAT-pm, 1 THU-am, 2 THU-pms, 1 TUE-pm, 2 WED-pms, 48.8ms
# Speed: 1.4ms preprocess, 48.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 Open, 1 SAT-am, 1 SAT-pm, 2 THU-pms, 1 WED-pm, 44.4ms
# Speed: 1.2ms preprocess, 44.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 FRI-pm, 1 SAT-am, 1 SAT-pm, 2 THU-pms, 1 TUE-pm, 2 WED-pms, 41.3ms
# Speed: 1.3ms preprocess, 41.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 SAT-pm, 45.2ms
# Speed: 1.2ms preprocess, 45.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 (no detections), 46.0ms
# Speed: 1.2ms preprocess, 46.0ms inference, 0.3ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 SAT-pm, 1 WED-pm, 40.9ms
# Speed: 1.3ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 SAT-pm, 39.9ms
# Speed: 1.3ms preprocess, 39.9ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 SAT-pm, 45.3ms
# Speed: 1.4ms preprocess, 45.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: SAT-pm
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: True
#
# 0: 288x480 1 SAT-pm, 1 WED-pm, 42.9ms
# Speed: 1.2ms preprocess, 42.9ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 WED-pm, 65.5ms
# Speed: 1.0ms preprocess, 65.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 SAT-am, 1 SAT-pm, 1 THU-am, 1 THU-pm, 1 WED-am, 2 WED-pms, 41.7ms
# Speed: 1.2ms preprocess, 41.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 SAT-am, 1 SAT-pm, 1 THU-pm, 2 WED-pms, 41.4ms
# Speed: 1.3ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 FRI-am, 1 SAT-am, 1 SAT-pm, 1 THU-pm, 2 WED-pms, 46.0ms
# Speed: 1.1ms preprocess, 46.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 40.9ms
# Speed: 1.5ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 43.3ms
# Speed: 1.2ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 40.3ms
# Speed: 1.2ms preprocess, 40.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 39.8ms
# Speed: 1.2ms preprocess, 39.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 44.8ms
# Speed: 1.2ms preprocess, 44.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 44.2ms
# Speed: 1.3ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.0ms
# Speed: 1.1ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 41.9ms
# Speed: 1.3ms preprocess, 41.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: Open
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 1 Open, 43.5ms
# Speed: 1.2ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 45.5ms
# Speed: 1.1ms preprocess, 45.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.2ms
# Speed: 1.1ms preprocess, 42.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 44.1ms
# Speed: 1.3ms preprocess, 44.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 41.2ms
# Speed: 1.1ms preprocess, 41.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 40.4ms
# Speed: 1.2ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 43.2ms
# Speed: 1.4ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 44.6ms
# Speed: 1.2ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 60.3ms
# Speed: 1.1ms preprocess, 60.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 41.0ms
# Speed: 1.2ms preprocess, 41.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 43.4ms
# Speed: 1.7ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 59.8ms
# Speed: 1.3ms preprocess, 59.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.1ms
# Speed: 1.1ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: Open
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 1 Open, 48.2ms
# Speed: 1.3ms preprocess, 48.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 40.6ms
# Speed: 1.3ms preprocess, 40.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 43.8ms
# Speed: 1.3ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 44.0ms
# Speed: 1.1ms preprocess, 44.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 53.3ms
# Speed: 1.1ms preprocess, 53.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 41.8ms
# Speed: 1.1ms preprocess, 41.8ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 48.7ms
# Speed: 1.8ms preprocess, 48.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 40.1ms
# Speed: 1.1ms preprocess, 40.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 51.8ms
# Speed: 1.8ms preprocess, 51.8ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 44.3ms
# Speed: 1.4ms preprocess, 44.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 43.5ms
# Speed: 1.1ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 51.1ms
# Speed: 1.1ms preprocess, 51.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 44.1ms
# Speed: 1.3ms preprocess, 44.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: Open
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 1 Open, 50.7ms
# Speed: 1.9ms preprocess, 50.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 50.5ms
# Speed: 1.1ms preprocess, 50.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 72.8ms
# Speed: 4.4ms preprocess, 72.8ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 94.5ms
# Speed: 1.9ms preprocess, 94.5ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 114.9ms
# Speed: 1.4ms preprocess, 114.9ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 140.2ms
# Speed: 1.3ms preprocess, 140.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 207.3ms
# Speed: 3.6ms preprocess, 207.3ms inference, 4.2ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 MON-am, 1 Open, 42.8ms
# Speed: 1.1ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 130.8ms
# Speed: 2.0ms preprocess, 130.8ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 480)
# Label: Open
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 1 Open, 66.2ms
# Speed: 1.3ms preprocess, 66.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 93.7ms
# Speed: 1.0ms preprocess, 93.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 98.8ms
# Speed: 1.6ms preprocess, 98.8ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 208.7ms
# Speed: 4.5ms preprocess, 208.7ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 112.8ms
# Speed: 1.8ms preprocess, 112.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 101.8ms
# Speed: 1.4ms preprocess, 101.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 64.0ms
# Speed: 2.7ms preprocess, 64.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 51.1ms
# Speed: 1.5ms preprocess, 51.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 48.9ms
# Speed: 1.1ms preprocess, 48.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.9ms
# Speed: 1.3ms preprocess, 42.9ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: Open
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 1 Open, 41.0ms
# Speed: 1.2ms preprocess, 41.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 43.4ms
# Speed: 1.2ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.1ms
# Speed: 1.2ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 MON-am, 1 Open, 41.8ms
# Speed: 1.3ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 47.9ms
# Speed: 1.3ms preprocess, 47.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 41.5ms
# Speed: 1.4ms preprocess, 41.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 49.6ms
# Speed: 1.1ms preprocess, 49.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 44.1ms
# Speed: 1.2ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 MON-am, 1 Open, 49.6ms
# Speed: 1.2ms preprocess, 49.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 40.8ms
# Speed: 1.1ms preprocess, 40.8ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.0ms
# Speed: 1.5ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 45.6ms
# Speed: 1.2ms preprocess, 45.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: Open
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 1 Open, 42.5ms
# Speed: 1.0ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.2ms
# Speed: 2.8ms preprocess, 42.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 46.9ms
# Speed: 1.2ms preprocess, 46.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.8ms
# Speed: 1.1ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.9ms
# Speed: 1.1ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 70.1ms
# Speed: 1.3ms preprocess, 70.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 46.0ms
# Speed: 1.1ms preprocess, 46.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 85.6ms
# Speed: 1.1ms preprocess, 85.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 150.0ms
# Speed: 1.0ms preprocess, 150.0ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 41.1ms
# Speed: 1.4ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 44.4ms
# Speed: 1.3ms preprocess, 44.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 49.1ms
# Speed: 1.2ms preprocess, 49.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: Open
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 1 Open, 43.9ms
# Speed: 1.1ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 55.9ms
# Speed: 1.0ms preprocess, 55.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 62.5ms
# Speed: 1.5ms preprocess, 62.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 40.0ms
# Speed: 1.2ms preprocess, 40.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 52.3ms
# Speed: 1.1ms preprocess, 52.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 47.1ms
# Speed: 1.2ms preprocess, 47.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 45.6ms
# Speed: 1.3ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 44.2ms
# Speed: 1.3ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 47.8ms
# Speed: 1.2ms preprocess, 47.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 41.3ms
# Speed: 1.2ms preprocess, 41.3ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 43.7ms
# Speed: 1.1ms preprocess, 43.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 39.7ms
# Speed: 1.2ms preprocess, 39.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 46.4ms
# Speed: 1.1ms preprocess, 46.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: Hands
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: True
#
# 0: 288x480 1 Hands, 41.8ms
# Speed: 1.1ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 39.7ms
# Speed: 1.2ms preprocess, 39.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 46.9ms
# Speed: 1.2ms preprocess, 46.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 41.7ms
# Speed: 1.1ms preprocess, 41.7ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Hands, 41.0ms
# ...
#
# 0: 288x480 1 Open, 1 PillBox, 44.8ms
# Speed: 1.4ms preprocess, 44.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 41.8ms
# Speed: 1.1ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 49.3ms
# Speed: 1.2ms preprocess, 49.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 46.0ms
# Speed: 1.5ms preprocess, 46.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 46.6ms
# Speed: 1.2ms preprocess, 46.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 42.7ms
# Speed: 1.1ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 46.0ms
# Speed: 1.5ms preprocess, 46.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: Open
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 1 Open, 1 PillBox, 55.6ms
# Speed: 1.2ms preprocess, 55.6ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.1ms
# Speed: 1.1ms preprocess, 42.1ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 43.2ms
# Speed: 1.2ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 45.0ms
# Speed: 1.2ms preprocess, 45.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 43.1ms
# Speed: 1.1ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 69.6ms
# Speed: 1.2ms preprocess, 69.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 55.5ms
# Speed: 1.1ms preprocess, 55.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.0ms
# Speed: 1.1ms preprocess, 42.0ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 40.2ms
# Speed: 1.4ms preprocess, 40.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Received from server: Wed-PM
# Received from server: Wed-PM
#
# 0: 288x480 1 Open, 54.1ms
# Speed: 1.1ms preprocess, 54.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 42.1ms
# Speed: 1.1ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 41.6ms
# Speed: 1.3ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 44.8ms
# Speed: 1.3ms preprocess, 44.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 41.1ms
# Speed: 1.1ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: Open
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 2 Opens, 1 PillBox, 44.3ms
# Speed: 1.2ms preprocess, 44.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 43.5ms
# Speed: 1.2ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 44.2ms
# Speed: 1.0ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 39.9ms
# Speed: 1.1ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 40.2ms
# Speed: 1.4ms preprocess, 40.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 43.1ms
# Speed: 1.1ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 40.9ms
# Speed: 1.4ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 43.2ms
# Speed: 1.4ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 53.2ms
# Speed: 1.4ms preprocess, 53.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.0ms
# Speed: 1.3ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 43.0ms
# Speed: 1.1ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 47.0ms
# Speed: 1.2ms preprocess, 47.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: Open
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 2 Opens, 60.3ms
# Speed: 1.1ms preprocess, 60.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 78.4ms
# Speed: 4.1ms preprocess, 78.4ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 70.5ms
# Speed: 1.5ms preprocess, 70.5ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 109.4ms
# Speed: 1.2ms preprocess, 109.4ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 480)
#
# Received from server: Wed-PM
# Received from server: Wed-PM
# 0: 288x480 2 Opens, 1 PillBox, 92.9ms
# Speed: 1.6ms preprocess, 92.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 156.0ms
# Speed: 1.3ms preprocess, 156.0ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 85.9ms
# Speed: 1.5ms preprocess, 85.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 47.4ms
# Speed: 1.0ms preprocess, 47.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 49.7ms
# Speed: 1.5ms preprocess, 49.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 44.3ms
# Speed: 1.3ms preprocess, 44.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
# Label: Open
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 1 Open, 40.9ms
# Speed: 1.0ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 41.2ms
# Speed: 1.1ms preprocess, 41.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 46.2ms
# Speed: 1.2ms preprocess, 46.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.1ms
# Speed: 1.1ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.4ms
# Speed: 1.2ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 45.0ms
# Speed: 1.5ms preprocess, 45.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.2ms
# Speed: 1.1ms preprocess, 42.2ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 66.7ms
# Speed: 1.1ms preprocess, 66.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 44.8ms
# Speed: 1.3ms preprocess, 44.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 43.6ms
# Speed: 1.2ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 44.8ms
# Speed: 1.1ms preprocess, 44.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 44.6ms
# Speed: 1.1ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 45.6ms
# Speed: 1.5ms preprocess, 45.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: Open
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 1 Open, 42.7ms
# Speed: 1.2ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# Received from server: Wed-PM
# 0: 288x480 1 Open, 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 40.4ms
# Speed: 1.3ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 45.1ms
# Speed: 1.2ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 39.9ms
# Speed: 1.1ms preprocess, 39.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 40.4ms
# Speed: 1.4ms preprocess, 40.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 41.9ms
# Speed: 1.3ms preprocess, 41.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.3ms
# Speed: 1.0ms preprocess, 42.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 51.6ms
# Speed: 1.3ms preprocess, 51.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 40.8ms
# Speed: 1.2ms preprocess, 40.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 44.5ms
# Speed: 1.1ms preprocess, 44.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 42.4ms
# Speed: 1.4ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: Open
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 1 Open, 43.0ms
# Speed: 1.1ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 42.1ms
# Speed: 1.1ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 41.3ms
# Speed: 1.4ms preprocess, 41.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 42.5ms
# Speed: 0.9ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 41.0ms
# Speed: 1.1ms preprocess, 41.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 45.9ms
# Speed: 1.3ms preprocess, 45.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 40.8ms
# Speed: 1.2ms preprocess, 40.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.4ms
# Speed: 1.0ms preprocess, 42.4ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 41.3ms
# Speed: 1.5ms preprocess, 41.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 43.2ms
# Speed: 1.2ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 41.4ms
# Speed: 1.1ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 39.8ms
# Speed: 2.8ms preprocess, 39.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: Open
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 2 Opens, 1 PillBox, 46.4ms
# Speed: 1.2ms preprocess, 46.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 1 PillBox, 41.4ms
# Speed: 1.1ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 43.4ms
# Speed: 1.1ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 44.3ms
# Speed: 1.2ms preprocess, 44.3ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 42.4ms
# Speed: 1.1ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 45.9ms
# Speed: 1.2ms preprocess, 45.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 49.5ms
# Speed: 1.3ms preprocess, 49.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 45.6ms
# Speed: 1.1ms preprocess, 45.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 44.8ms
# Speed: 1.2ms preprocess, 44.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 43.8ms
# Speed: 1.3ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 45.5ms
# Speed: 1.2ms preprocess, 45.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# Received from server: Wed-PM
# Received from server: Wed-PM
# 0: 288x480 2 Opens, 40.7ms
# Speed: 1.1ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 41.7ms
# Speed: 1.0ms preprocess, 41.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: Open
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
#
# 0: 288x480 2 Opens, 43.9ms
# Speed: 1.3ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 44.1ms
# Speed: 1.2ms preprocess, 44.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 42.4ms
# Speed: 1.4ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 43.5ms
# Speed: 1.1ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 40.7ms
# Speed: 1.3ms preprocess, 40.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 42.6ms
# Speed: 1.3ms preprocess, 42.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 43.6ms
# Speed: 1.4ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 42.4ms
# Speed: 1.1ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 3 Opens, 1 PillBox, 44.8ms
# Speed: 1.1ms preprocess, 44.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 41.1ms
# Speed: 1.1ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 43.4ms
# Speed: 1.1ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 2 Opens, 1 PillBox, 44.7ms
# Speed: 2.9ms preprocess, 44.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
#
# 0: 288x480 1 Open, 43.2ms
# Speed: 1.1ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 480)
# Label: Open
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: True
# Received from server: Wed-PM
# Received from server: Wed-PM
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import cv2  # OpenCV library for computer vision tasks
from ultralytics import YOLO  # YOLO model for object detection
from PIL import Image, ImageTk  # PIL for image processing and integration with Tkinter
import tkinter as tk  # Tkinter for GUI
import socket  # Socket for network communication
import threading  # Threading for concurrent operations
import time  # Time for handling time-related operations
import logging  # For logging configurations
import sys  # For redirecting standard output
import os  # For setting environment variables
import contextlib  # For suppressing print statements

# Suppress logging from specific libraries
logging.getLogger('ultralytics').setLevel(logging.ERROR)
logging.getLogger('torch').setLevel(logging.ERROR)
logging.getLogger('PIL').setLevel(logging.ERROR)

# Suppress OpenCV debug prints using environment variable
os.environ['OPENCV_LOG_LEVEL'] = 'ERROR'

# Context manager to suppress print statements
@contextlib.contextmanager
def suppress_stdout():
    with open(os.devnull, 'w') as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout

# Load the trained YOLOv8 model
try:
    with suppress_stdout():
        model = YOLO('runs/detect/train/weights/best.pt')
except Exception as e:
    print(f"Error loading model: {e}")
    exit()

# Define the class names
class_names = ['FRI-am', 'FRI-pm', 'Hands', 'MON-am', 'MON-pm', 'Open', 'Pill', 'PillBox', 'SAT-am', 'SAT-pm', 'SUN-am', 'SUN-pm', 'THU-am', 'THU-pm', 'TUE-am', 'TUE-pm', 'WED-am', 'WED-pm']

# Define the day and time slots for the pillbox compartments
day_time_slots = ['MON-am', 'MON-pm', 'TUE-am', 'TUE-pm', 'WED-am', 'WED-pm', 'THU-am', 'THU-pm', 'FRI-am', 'FRI-pm', 'SAT-am', 'SAT-pm', 'SUN-am', 'SUN-pm']

# Define colors for each class visualization
class_colors = {
    'FRI-am': (0, 255, 255),
    'FRI-pm': (255, 255, 0),
    'Hands': (0, 255, 0),
    'MON-am': (255, 0, 255),
    'MON-pm': (0, 255, 255),
    'Open': (255, 255, 0),
    'Pill': (255, 0, 0),
    'PillBox': (0, 255, 255),
    'SAT-am': (255, 165, 0),
    'SAT-pm': (255, 69, 0),
    'SUN-am': (128, 0, 128),
    'SUN-pm': (75, 0, 130),
    'THU-am': (0, 255, 255),
    'THU-pm': (0, 128, 128),
    'TUE-am': (255, 0, 255),
    'TUE-pm': (128, 0, 0),
    'WED-am': (0, 0, 255),
    'WED-pm': (0, 128, 0)
}

# Server address and port for Raspberry Pi
server_address = ('192.168.168.167', 1443)  # Change this to your Raspberry Pi IP and port

# Global vars for use in methods/threads
client_socket = None
receive_thread = None
shutdown_flag = threading.Event()
last_debug_time = time.time()
debug_interval = 2
current_day_time = None

def setup_socket_client():
    global client_socket, receive_thread
    client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)  # Create a socket instance
    client_socket.connect(server_address)  # Connect to specified server
    print("Connected to server")

    # Start a thread to handle incoming messages
    receive_thread = threading.Thread(target=receive_messages, args=(client_socket, shutdown_flag))
    receive_thread.start()

def receive_messages(sock, shutdown_flag):
    global current_day_time
    sock.settimeout(1)  # Set a timeout on the socket so we can check shutdown_flag.is_set in the loop, instead of blocking
    try:
        while not shutdown_flag.is_set():  # As long as ctrl+c is not pressed
            try:
                data = sock.recv(1024)  # Try to receive 1024 bytes of data (maximum amount; can be less)
                if not data:  # When no data is received, try again (and shutdown flag is checked again)
                    break
                current_day_time = data.decode()
                print("Received from server:", current_day_time)  # Print the received data, or do something with it
            except socket.timeout:  # When no data comes within timeout, try again
                continue
    except Exception as e:
        if not shutdown_flag.is_set():
            print(f"Connection error: {e}")
    finally:
        sock.close()

def request_date_time():
    global client_socket
    try:
        client_socket.sendall("Request date and time".encode())
    except Exception as e:
        print(f"Failed to request date and time: {e}")

# Function to draw bounding boxes with different colors
def draw_bounding_boxes(image, results):
    global last_debug_time, current_day_time
    boxes = results[0].boxes.xyxy.cpu().numpy()
    confs = results[0].boxes.conf.cpu().numpy()
    classes = results[0].boxes.cls.cpu().numpy()
    
    pillbox_detected = False
    compartment_open_detected = False
    wrong_compartment_opened = False
    detected_labels = []  # Initialize an empty list to store detected labels

    for i, box in enumerate(boxes):
        x1, y1, x2, y2 = map(int, box)
        conf = confs[i]
        cls = int(classes[i])
        label = class_names[cls]
        if label in day_time_slots:
            detected_labels.append(label)  # Append the detected label to the list

        color = class_colors.get(label, (0, 0, 255))  # Default to blue if not found
        
        cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)
        cv2.putText(image, f'{label} {confs[i]:.2f}', (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)
        
        if label == 'PillBox':
            pillbox_detected = True

        if label == 'Open':
            compartment_open_detected = True
            
        # # Check if the open compartment matches the expected compartment
        # if label == ' Open' and current_day_time not in:
        #     print(f"Expected: {current_day_time}, Detected: {label}")
        #     wrong_compartment_opened = True

    # Check if it's time to print debug statements
    if last_debug_time + debug_interval < time.time():
        # Debug statements to verify logic
        print(f"Current Day and Time: {current_day_time}")
        print(f"Pillbox Detected: {pillbox_detected}")
        print(f"Compartment Open Detected: {compartment_open_detected}")
        print(f"Wrong Compartment Opened: {wrong_compartment_opened}")
        print(f"Detected Labels: {detected_labels}")
        # Update the last debug time
        last_debug_time = time.time()
        
    if pillbox_detected and compartment_open_detected and wrong_compartment_opened:
        send_buzzer_notification()

def send_buzzer_notification():
    global client_socket
    try:
        client_socket.sendall("Wrong pill detected".encode())
    except Exception as e:
        print(f"Failed to send buzzer notification: {e}")

# AI part
def process_frame(frame):
    # Perform inference with the YOLOv8 model
    try:
        with suppress_stdout():
            results = model(frame)
    except Exception as e:
        print(f"Error performing inference: {e}")
        return frame

    # Annotate the frame with detection results
    draw_bounding_boxes(frame, results)

    return frame

# Tkinter GUI part
def update_frame():
    ret, frame = cap.read()
    if ret:
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Convert colorspace from BGR to RGB
        frame = process_frame(frame)  # Calls process_frame(frame) to perform object detection and annotation on the frame.
        img = Image.fromarray(frame)  # Converts the processed frame (which is a numpy array) to a PIL Image object using Image.fromarray.
        imgtk = ImageTk.PhotoImage(image=img)  # Converts the PIL Image to a format suitable for displaying in a Tkinter GUI using ImageTk.PhotoImage.
        label_img.imgtk = imgtk  # Updates the image displayed in the Tkinter Label widget (label_img) with the new frame by setting its image attribute to imgtk.
        label_img.configure(image=imgtk)
    else:
        print("Error reading frame from webcam")
    label_img.after(10, update_frame)  # Schedule the update after 10 milliseconds

# Initialize the webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Setup Tkinter window
window = tk.Tk()
window.title("Pill Detection")
window.geometry("800x600")

# Create a label to display the webcam feed
label_img = tk.Label(window)
label_img.pack()

# Start the socket client
setup_socket_client()

# Request the initial date and time
request_date_time()

# Start the webcam feed update
update_frame()

# Start the Tkinter event loop
window.mainloop()

# Release the webcam
cap.release()
# Out:
# [ WARN:0@1153.565] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_f6tvh9615u/croot/opencv-suite_1691620375715/work/modules/videoio/src/cap_gstreamer.cpp (862) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# Connected to server
# Received from server: Wed-PM
# Received from server: Wed-PM
# Current Day and Time: Wed-PM
# Pillbox Detected: True
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-pm', 'MON-pm', 'TUE-pm', 'SAT-am', 'WED-am', 'TUE-am', 'SUN-pm', 'THU-pm', 'MON-am', 'THU-am', 'FRI-am', 'SUN-am', 'SAT-pm', 'FRI-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: True
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-pm', 'MON-pm', 'SAT-am', 'TUE-pm', 'WED-am', 'THU-pm', 'TUE-am', 'SUN-pm', 'MON-am', 'THU-am', 'FRI-am', 'FRI-pm', 'SAT-pm', 'SUN-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: True
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-pm', 'MON-pm', 'TUE-pm', 'SAT-am', 'WED-am', 'TUE-am', 'THU-pm', 'MON-am', 'SUN-pm', 'THU-am', 'FRI-am', 'SUN-am', 'SAT-pm', 'FRI-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: True
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-pm', 'MON-pm', 'TUE-pm', 'SAT-am', 'WED-am', 'THU-pm', 'TUE-am', 'SUN-pm', 'MON-am', 'FRI-am', 'THU-am', 'SUN-am', 'FRI-pm', 'SAT-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: True
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-pm', 'MON-pm', 'TUE-pm', 'SAT-am', 'WED-am', 'THU-pm', 'TUE-am', 'SUN-pm', 'MON-am', 'SUN-am', 'THU-am', 'SAT-pm', 'FRI-am', 'FRI-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: True
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-pm', 'MON-pm', 'TUE-pm', 'SAT-am', 'WED-am', 'THU-pm', 'SUN-pm', 'TUE-am', 'THU-am', 'MON-am', 'SUN-am', 'FRI-am', 'SAT-pm', 'FRI-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: True
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-pm', 'MON-pm', 'TUE-pm', 'SAT-am', 'THU-pm', 'WED-am', 'MON-am', 'TUE-am', 'SUN-pm', 'SUN-am', 'THU-am', 'FRI-am', 'SAT-pm', 'FRI-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: True
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-pm', 'MON-pm', 'TUE-pm', 'SAT-am', 'THU-pm', 'WED-am', 'SUN-pm', 'TUE-am', 'MON-am', 'SUN-am', 'FRI-am', 'THU-am', 'SAT-pm', 'FRI-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: True
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-pm', 'MON-pm', 'TUE-pm', 'SAT-am', 'WED-am', 'THU-pm', 'SUN-pm', 'TUE-am', 'MON-am', 'SUN-am', 'FRI-am', 'THU-am', 'FRI-pm', 'SAT-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: True
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-pm', 'MON-pm', 'SAT-am', 'TUE-pm', 'WED-am', 'TUE-am', 'THU-pm', 'SUN-pm', 'MON-am', 'THU-am', 'FRI-am', 'SUN-am', 'SAT-pm', 'FRI-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: True
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-pm', 'MON-pm', 'TUE-pm', 'SAT-am', 'WED-am', 'THU-pm', 'TUE-am', 'MON-am', 'SUN-am', 'SUN-pm', 'FRI-am', 'THU-am', 'FRI-pm', 'SAT-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: True
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-pm', 'MON-pm', 'TUE-pm', 'SAT-am', 'WED-am', 'THU-pm', 'TUE-am', 'MON-am', 'SUN-pm', 'THU-am', 'SUN-am', 'FRI-am', 'FRI-pm', 'SAT-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: True
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-pm', 'MON-pm', 'TUE-pm', 'SAT-am', 'WED-am', 'THU-pm', 'TUE-am', 'SUN-pm', 'MON-am', 'THU-am', 'FRI-am', 'SUN-am', 'FRI-pm', 'SAT-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: True
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['WED-pm', 'MON-pm', 'TUE-pm', 'SAT-am', 'WED-am', 'THU-pm', 'TUE-am', 'SUN-pm', 'THU-am', 'MON-am', 'FRI-am', 'FRI-pm', 'SUN-am', 'SAT-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['SAT-am', 'FRI-am', 'SAT-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: False
# Wrong Compartment Opened: False
# Detected Labels: ['SAT-am', 'SAT-pm', 'FRI-am', 'FRI-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'MON-am', 'TUE-am', 'WED-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am', 'WED-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am', 'WED-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am', 'WED-am', 'MON-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am', 'MON-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am', 'WED-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am', 'WED-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'TUE-am', 'MON-am', 'MON-am', 'WED-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am', 'WED-am', 'MON-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am', 'WED-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am', 'WED-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am', 'WED-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'TUE-am', 'MON-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'TUE-am', 'MON-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: []
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am', 'WED-am', 'SUN-pm', 'MON-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'TUE-am', 'MON-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am', 'TUE-am']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm']
# Current Day and Time: Wed-PM
# Pillbox Detected: False
# Compartment Open Detected: True
# Wrong Compartment Opened: False
# Detected Labels: ['MON-pm', 'MON-am']
